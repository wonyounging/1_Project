# %%
import pandas as pd
import numpy as np

# %%
from matplotlib import font_manager, rc
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['axes.unicode_minus'] = False  # minus 표시
plt.rc('font', family='Malgun Gothic')

# %%
# 이상치 제거 파일 2003-2022 파일 전체 국적 비교

# %%
file_path = "박스오피스_일별(2003~2022)_장르_수정.csv"
mv_2017 = pd.read_csv(file_path)
mv_2017
file_path2 = '누적관객수_백만명_이상_766개.csv'
mv_2003 = pd.read_csv(file_path2)

# %%
mv_2003
# Out:
#        순위      영화명         개봉일        등급      장르 대표국적  국적        제작사  \
# 0      34       명량  2014-07-30  15세이상관람가   사극,액션   한국  한국  (주)빅스톤픽쳐스
# 1       7       명량  2014-07-30  15세이상관람가   사극,액션   한국  한국  (주)빅스톤픽쳐스
# 2      22       명량  2014-07-30  15세이상관람가   사극,액션   한국  한국  (주)빅스톤픽쳐스
# 3       9       명량  2014-07-30  15세이상관람가   사극,액션   한국  한국  (주)빅스톤픽쳐스
# 4       9       명량  2014-07-30  15세이상관람가   사극,액션   한국  한국  (주)빅스톤픽쳐스
# ...    ..      ...         ...       ...     ...  ...  ..        ...
# 65789  58  스카이스크래퍼  2018-07-11  12세이상관람가  액션,스릴러   미국  미국        NaN
# 65790  59  스카이스크래퍼  2018-07-11  12세이상관람가  액션,스릴러   미국  미국        NaN
# 65791  49  스카이스크래퍼  2018-07-11  12세이상관람가  액션,스릴러   미국  미국        NaN
# 65792  46  스카이스크래퍼  2018-07-11  12세이상관람가  액션,스릴러   미국  미국        NaN
# 65793  48  스카이스크래퍼  2018-07-11  12세이상관람가  액션,스릴러   미국  미국        NaN
#
#                        배급사        감독  \
# 0                (주)씨제이이엔엠       김한민
# 1                (주)씨제이이엔엠       김한민
# ...

# %%
mv_2017.groupby('영화명')['개봉일'].count()
mv_2003.groupby('영화명')['개봉일'].count()
# Out:
# 영화명
# #살아있다            68
# 007 노 타임 투 다이    60
# 007 스카이폴         58
# 007 스펙터          43
# 007 카지노 로얄       57
#                  ..
# 후궁 : 제왕의 첩       83
# 흡혈형사 나도열         53
# 히말라야             87
# 히트맨              77
# 힘을 내요, 미스터 리     75
# Name: 개봉일, Length: 775, dtype: int64

# %%
mv_counts = mv_2017.groupby('영화명')['개봉일'].count().reset_index(name='개수')
mv_counts
mv_counts2 = mv_2003.groupby('영화명')['개봉일'].count().reset_index(name='개수')

# %%
 mv_2017.groupby('영화명')['개봉일'].size()
# Out:
# 영화명
# #살아있다            68
# #아이엠히어           29
# #위왓치유            43
# ...ing           27
# 0.0MHz           31
#                ...
# 힘내세요, 병헌씨       102
# 힘을 내요, 미스터 리     75
# 힙스터: 안개의 덫        1
# 힛쳐               12
# ＡＶ여배우의 자취방        1
# Name: 개봉일, Length: 17768, dtype: int64

# %%
mv_counts_sort = mv_counts.sort_values(by='개수', ascending=False)
mv_counts2_sort = mv_counts2.sort_values(by='개수', ascending=False)

# %%
mv_20 = mv_counts_sort.iloc[:20,:]
mv_20
mv_20_2 = mv_counts2_sort.iloc[:20,:]
mv_20_2
# Out:
#                    영화명   개수
# 195               라라랜드  889
# 137            너의 이름은.  763
# 349             비긴 어게인  553
# 208              레미제라블  335
# 471             어바웃 타임  317
# 533             위대한 쇼맨  310
# 100                기생충  304
# 365               색, 계  303
# 534               위플래쉬  282
# 225          마당을 나온 암탉  281
# 93                그래비티  270
# 97   극장판 귀멸의 칼날: 무한열차편  264
# 241              맘마미아!  247
# 77                국제시장  236
# 560                인셉션  234
# 153             다크 나이트  228
# 564              인터스텔라  227
# 147    님아, 그 강을 건너지 마오  223
# 468            어거스트 러쉬  220
# 693              트랜스포머  215

# %%
index1 = list(mv_20['영화명'])
index2 = list(mv_20_2['영화명'])

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
label = []
label2=[]

# %%
# x = np.arange(20)
# years = ['2018', '2019', '2020']
# values = [100, 400, 900]
# plt.bar(x, values)
# plt.xticks(x, years)

# plt.show()

# %%
# plt.rc('font', family='NanumMyeongjo') # For Windows
# print(plt.rcParams['font.family'])

# %%
mv_20.plot.bar(x='영화명', y='개수', rot=80, figsize=(10, 5), fontsize=13, color='paleturquoise')
plt.title('상영횟수')
plt.xlabel('영화명', fontsize=12)
plt.ylabel('상영건수', fontsize=12)
# plt.grid(True)
plt.show()

# %%
# 백만이상 관람객 상영건수 
mv_20_2.plot.bar(x='영화명', y='개수', rot=80, figsize=(10, 5), fontsize=13, color='cadetblue')
plt.title('상영횟수', fontsize=15)
plt.xlabel('영화명', fontsize=12)
plt.ylabel('상영건수', fontsize=12)
# plt.grid(True)
plt.show()

# %%
mv_20[mv_20['영화명']==index1]
mv_20_2[mv_20_2['영화명']==index2]
# Out:
#                    영화명   개수
# 195               라라랜드  889
# 137            너의 이름은.  763
# 349             비긴 어게인  553
# 208              레미제라블  335
# 471             어바웃 타임  317
# 533             위대한 쇼맨  310
# 100                기생충  304
# 365               색, 계  303
# 534               위플래쉬  282
# 225          마당을 나온 암탉  281
# 93                그래비티  270
# 97   극장판 귀멸의 칼날: 무한열차편  264
# 241              맘마미아!  247
# 77                국제시장  236
# 560                인셉션  234
# 153             다크 나이트  228
# 564              인터스텔라  227
# 147    님아, 그 강을 건너지 마오  223
# 468            어거스트 러쉬  220
# 693              트랜스포머  215

# %%
mv_2017['기준일'] = pd.to_datetime(mv_2017['기준일'],format='%Y-%m-%d')
mv_2003['기준일'] = pd.to_datetime(mv_2003['기준일'],format='%Y-%m-%d')

# %%
mv_preprocess = mv_2017.loc[mv_2017.groupby(['영화명'])['기준일'].idxmax()]
mv_preprocess
mv_preprocess2 = mv_2003.loc[mv_2003.groupby(['영화명'])['기준일'].idxmax()]
mv_preprocess2
# Out:
#         순위            영화명         개봉일        등급              장르 대표국적     국적  \
# 42231   29          #살아있다  2020-06-24  15세이상관람가             드라마   한국     한국
# 57942   87  007 노 타임 투 다이  2021-09-29  12세이상관람가              액션   미국     미국
# 34139   44       007 스카이폴  2012-10-26  15세이상관람가              액션   미국  미국,영국
# 44009   49        007 스펙터  2015-11-11  15세이상관람가  액션,어드벤처,범죄,스릴러   영국  영국,미국
# 65402   46     007 카지노 로얄  2006-12-21  15세이상관람가              액션   미국     미국
# ...    ...            ...         ...       ...             ...  ...    ...
# 31227   93     후궁 : 제왕의 첩  2012-06-06   청소년관람불가       사극,멜로/로맨스   한국     한국
# 50330   47       흡혈형사 나도열  2006-02-09    15세관람가         코미디,드라마   한국     한국
# 6488    83           히말라야  2015-12-16  12세이상관람가             드라마   한국     한국
# 33897  106            히트맨  2020-01-22  15세이상관람가          코미디,액션   한국     한국
# 59546   15   힘을 내요, 미스터 리  2019-09-11  12세이상관람가         코미디,드라마   한국     한국
#
# ...

# %%
countr_counts = mv_preprocess.groupby('대표국적')['대표국적'].count()
colors = ['#40E0D0', '#ffc000', '#56B4E9', '#FFFFF0', '#FFEBCD', '#D2691E', '#FFFAF0', '#8fd9b6', '#ff9999']

plt.figure(figsize=(7, 7))

plt.pie(country_counts, labels=country_counts.index, autopct='%1.1f%%', colors=colors)
plt.axis('equal')
plt.title('대표국적 비율', fontsize=18)
plt.show()

# %%
country_counts2 = mv_preprocess2.groupby('대표국적')['대표국적'].count()
colors = ['#40E0D0', '#ffc000', '#56B4E9', '#FFFFF0', '#FFEBCD', '#D2691E', '#FFFAF0', '#8fd9b6', '#ff9999']

plt.figure(figsize=(7,7))

plt.pie(country_counts2, labels=country_counts2.index, autopct='%1.1f%%', colors=colors)
plt.axis('equal')
plt.title('대표국적 비율', fontsize=18)
plt.show()

# %%
country_counts_others = mv_preprocess.groupby('대표국적')['대표국적'].count().reset_index(name='영화개수')
country_counts_others
# Out:
#         대표국적  영화개수
# 0        그리스    11
# 1         기타   519
# 2   남아프리카공화국     3
# 3       네덜란드    34
# 4       노르웨이    34
# ..       ...   ...
# 70       필리핀     5
# 71        한국  5668
# 72       헝가리    37
# 73        호주    96
# 74        홍콩   313
#
# [75 rows x 2 columns]

# %%
country_counts2_others = mv_preprocess2.groupby('대표국적')['대표국적'].count().reset_index(name='영화개수')
country_counts2_others
# Out:
#   대표국적  영화개수
# 0   독일     1
# 1   미국   327
# 2  벨기에     1
# 3   영국     6
# 4   일본     5
# 5   중국     4
# 6  프랑스     3
# 7   한국   428

# %%
country_counts_others[country_counts_others.대표국적 == '미국']
# Out:
#    대표국적  영화개수
# 17   미국  4290

# %%
country_counts_others[country_counts_others.대표국적 == '한국']
# Out:
#    대표국적  영화개수
# 71   한국  5668

# %%
country_counts2_others[country_counts2_others.대표국적 == '미국']
# Out:
#   대표국적  영화개수
# 1   미국   327

# %%
country_counts2_others[country_counts2_others.대표국적 == '한국']
# Out:
#   대표국적  영화개수
# 7   한국   428

# %%
country_counts2_others[country_counts2_others.대표국적 == '일본']
# Out:
#   대표국적  영화개수
# 4   일본     5

# %%
cc= country_counts_others[country_counts_others.영화개수 >= 100]
cc
# Out:
#     대표국적  영화개수
# 1     기타   519
# 8     독일   261
# 9    러시아   154
# 17    미국  4290
# 29   스페인   200
# 38    영국   642
# 48  이탈리아   149
# 51    일본  3122
# 53    중국   476
# 58   캐나다   219
# 68   프랑스   781
# 71    한국  5668
# 74    홍콩   313

# %%
cc2= country_counts2_others[country_counts2_others.영화개수 >= 100]
cc2
# Out:
#   대표국적  영화개수
# 1   미국   327
# 7   한국   428

# %%
# 개봉 영화 국가별 갯수 
cc.sort_values(by=['영화개수'], axis=0)
# Out:
#     대표국적  영화개수
# 48  이탈리아   149
# 9    러시아   154
# 29   스페인   200
# 58   캐나다   219
# 8     독일   261
# 74    홍콩   313
# 53    중국   476
# 1     기타   519
# 38    영국   642
# 68   프랑스   781
# 51    일본  3122
# 17    미국  4290
# 71    한국  5668

# %%
# 결론 비율 을 따져 보면 , 미국 영화 와 한국 영화는 개봉 비율로 따졌을때 다른 영화에 비해 흥행률이 높은것을 알 수 있음

# %%
#백만이상 영화 국가별 갯수 
cc2.sort_values(by=['영화개수'], axis=0)
# Out:
#   대표국적  영화개수
# 1   미국   327
# 7   한국   428

# %%
others_sum = country_counts_others[country_counts_others['영화개수'] < 100]['영화개수'].sum()
others_sum
# Out:
# 962

# %%
# 액션 영화 국가별 분석 

mv_2017
# Out:
#         순위                영화명         개봉일        등급        장르 대표국적  국적  \
# 0        1          동갑내기 과외하기  2003-02-07    12세관람가       코미디   한국  한국
# 1        1         매트릭스3 레볼루션  2003-11-05    15세관람가  SF,액션,범죄   미국  미국
# 2        2             위대한 유산  2003-10-24    15세관람가       코미디   한국  한국
# 3        3                황산벌  2003-10-17    15세관람가       코미디   한국  한국
# 4        4              아이덴티티  2003-10-31    15세관람가    범죄,스릴러   미국  미국
# ...     ..                ...         ...       ...       ...  ...  ..
# 482747  34              애프터 양  2022-06-01     전체관람가    드라마,SF   미국  미국
# 482748  31               더 메뉴  2022-12-07  15세이상관람가       스릴러   미국  미국
# 482749  28  양자경의 더 모든 날 모든 순간  2022-11-23  15세이상관람가    액션,코미디   미국  미국
# 482750  26           캐리와 슈퍼콜라  2023-01-18     전체관람가     애니메이션   한국  한국
# 482751  30                 수라  2023-06-21     전체관람가     다큐멘터리   한국  한국
#
#                     제작사                   배급사               감독  \
# ...

# %%
mv_action = mv_2017[mv_2017['장르'].str.contains('액션')]
mv_adventure = mv_2017[mv_2017['장르'].str.contains('어드벤처')]

# %%
mv_counts_action = mv_action.groupby('영화명')['개봉일'].count().reset_index(name='개수')
mv_counts_adventure = mv_adventure.groupby('영화명')['개봉일'].count().reset_index(name='개수')

# %%
mv_counts_acction_sort = mv_counts_action.sort_values(by='개수', ascending=False)
mv_counts_adventure_sort = mv_counts_adventure.sort_values(by='개수', ascending=False)

# %%
mv_action_20 = mv_counts_acction_sort.iloc[:20,:]
mv_adventure_20 = mv_counts_adventure_sort.iloc[:20,:]

# %%
index3 = list(mv_action_20['영화명'])
index3
# Out:
# ['벤허',
#  '영웅본색',
#  '불한당: 나쁜 놈들의 세상',
#  '다크 나이트',
#  '영웅본색 2',
#  '트랜스포머',
#  '테넷',
#  '매드 맥스: 분노의 도로',
#  '아바타',
#  '점박이:한반도의 공룡3D',
#  '설국열차',
#  '포드 V 페라리',
#  '레옹',
#  '탑건: 매버릭',
#  '명량',
#  '신세계',
#  '모가디슈',
#  '암살',
#  '동사서독 리덕스',
#  '아저씨']

# %%
index4 = list(mv_adventure_20['영화명'])
index4
# Out:
# ['그랜드 부다페스트 호텔',
#  '늑대아이',
#  '알라딘',
#  '문라이즈 킹덤',
#  '트랜스포머',
#  '겨울왕국',
#  '천로역정: 천국을 찾아서',
#  '매드 맥스: 분노의 도로',
#  '아바타',
#  '라이프 오브 파이',
#  '점박이:한반도의 공룡3D',
#  '드래곤 길들이기',
#  '라이온 킹',
#  '잃어버린 세계를 찾아서',
#  '더 폴: 오디어스와 환상의 문',
#  '다이노 타임',
#  '그린 나이트',
#  '어벤져스: 인피니티 워',
#  '좋은 놈, 나쁜 놈, 이상한 놈',
#  '스파이더맨: 노 웨이 홈']

# %%
mv_action_20.plot.bar(x='영화명', y='개수', rot=80, figsize=(10, 5), fontsize=12, color='wheat')
plt.title('상영횟수', fontsize= 15)
plt.xlabel('영화명', fontsize=12)
plt.ylabel('상영건수', fontsize=12)
# plt.grid(True)
plt.show()

# %%
mv_adventure_20.plot.bar(x='영화명', y='개수', rot=80, figsize=(10, 5), fontsize=12, color='khaki')
plt.title('상영횟수', fontsize=15)
plt.ylabel('상영건수', fontsize=12)
plt.ylabel('상영건수', fontsize=12)
# plt.grid(True)
plt.show()

# %%
mv_action_20[mv_action_20['영화명']==index3]
# Out:
#                  영화명   개수
# 1108              벤허  355
# 1876            영웅본색  330
# 1164  불한당: 나쁜 놈들의 세상  288
# 373           다크 나이트  228
# 1877          영웅본색 2  216
# 2654           트랜스포머  215
# 2610              테넷  197
# 826    매드 맥스: 분노의 도로  194
# 1628             아바타  193
# 2176   점박이:한반도의 공룡3D  188
# 1327            설국열차  186
# 2776        포드 V 페라리  183
# 690               레옹  177
# 2575         탑건: 매버릭  174
# 881               명량  171
# 1575             신세계  165
# 884             모가디슈  165
# 1696              암살  163
# 554         동사서독 리덕스  160
# 1662             아저씨  155

# %%
mv_adventure_20[mv_adventure_20['영화명']==index4]
# Out:
#                    영화명   개수
# 58        그랜드 부다페스트 호텔  387
# 121               늑대아이  314
# 563                알라딘  228
# 314            문라이즈 킹덤  215
# 839              트랜스포머  215
# 39                겨울왕국  200
# 747      천로역정: 천국을 찾아서  198
# 279      매드 맥스: 분노의 도로  194
# 541                아바타  193
# 212          라이프 오브 파이  190
# 705      점박이:한반도의 공룡3D  188
# 182           드래곤 길들이기  170
# 211              라이온 킹  167
# 684       잃어버린 세계를 찾아서  156
# 160   더 폴: 오디어스와 환상의 문  151
# 133             다이노 타임  149
# 59              그린 나이트  147
# 586       어벤져스: 인피니티 워  147
# 722  좋은 놈, 나쁜 놈, 이상한 놈  146
# 493      스파이더맨: 노 웨이 홈  144

# %%
mv_action['기준일'] = pd.to_datetime(mv_action['기준일'],format='%Y-%m-%d')
mv_adventure['기준일'] = pd.to_datetime(mv_adventure['기준일'],format='%Y-%m-%d')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_28084\764709354.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mv_action['기준일'] = pd.to_datetime(mv_action['기준일'],format='%Y-%m-%d')
# C:\Users\user\AppData\Local\Temp\ipykernel_28084\764709354.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mv_adventure['기준일'] = pd.to_datetime(mv_adventure['기준일'],format='%Y-%m-%d')

# %%
mv_preprocess_action = mv_action.loc[mv_action.groupby(['영화명'])['기준일'].idxmax()]
mv_preprocess_adventure = mv_adventure.loc[mv_adventure.groupby(['영화명'])['기준일'].idxmax()]

# %%
country_counts_action = mv_preprocess_action.groupby('대표국적')['대표국적'].count()
colors = ['#40E0D0', '#ffc000', '#56B4E9', '#FFFFF0', '#FFEBCD', '#D2691E', '#FFFAF0', '#8fd9b6', '#ff9999']

plt.figure(figsize=(7, 8))
plt.pie(country_counts_action, labels=country_counts_action.index, autopct='%1.1f%%', colors=colors)
plt.axis('equal')
plt.title('대표국적 비율', fontsize=15)
plt.show()

# %%
country_counts_adventure = mv_preprocess_adventure.groupby('대표국적')['대표국적'].count()
colors = ['#FFFFF0', '#ffc000', '#40E0D0', '#FFEBCD', '#D2691E', '#FFFAF0', '#56B4E9', '#8fd9b6', '#ff9999']
plt.figure(figsize=(7, 7))

plt.pie(country_counts_adventure, labels=country_counts_adventure.index, autopct='%1.1f%%', colors=colors)
plt.axis('equal')
plt.title('대표국적 비율', fontsize=15)
plt.show()

# %%
country_counts_action_others = mv_preprocess_action.groupby('대표국적')['대표국적'].count().reset_index(name='영화개수')
country_counts_action_others
# Out:
#            대표국적  영화개수
# 0            기타    11
# 1          네덜란드     5
# 2          노르웨이     5
# 3          뉴질랜드     7
# 4            대만     7
# 5           덴마크     5
# 6            독일    32
# 7           러시아    61
# 8         말레이시아     5
# 9           멕시코     4
# 10          모로코     1
# 11           몰타     1
# 12           미국  1370
# 13        베네수엘라     2
# 14          베트남     4
# 15          벨기에     1
# 16         불가리아     1
# 17          브라질     2
# 18          스웨덴     7
# 19          스위스     1
# 20          스페인    21
# 21  아랍에미리트연합국정부     1
# 22        아르헨티나     1
# 23        아이슬란드     1
# 24         아일랜드     1
# 25        에스토니아     1
# 26           영국   121
# 27        오스트리아     1
# 28       우즈베키스탄     2
# 29        우크라이나     6
# 30           이란     3
# 31         이스라엘     4
# 32         이탈리아    16
# 33           인도    11
# 34        인도네시아     7
# 35           일본   231
# 36           중국   270
# 37           칠레     1
# 38        카자흐스탄     5
# 39          캐나다    59
# ...

# %%
country_counts_adventure_others = mv_preprocess_adventure.groupby('대표국적')['대표국적'].count().reset_index(name='영화개수')
country_counts_adventure_others
# Out:
#            대표국적  영화개수
# 0           그리스     1
# 1            기타     5
# 2      남아프리카공화국     1
# 3          네덜란드     2
# 4          노르웨이     8
# 5          뉴질랜드     3
# 6           덴마크     8
# 7            독일    23
# 8           러시아    30
# 9         말레이시아     3
# 10          멕시코     4
# 11           몰타     1
# 12           미국   497
# 13          벨기에     8
# 14          브라질     1
# 15           서독     1
# 16          스웨덴     3
# 17          스위스     1
# 18          스페인    16
# 19  아랍에미리트연합국정부     2
# 20        아르헨티나     2
# 21        아이슬란드     2
# 22         아일랜드     3
# 23           영국    50
# 24        오스트리아     1
# 25        우크라이나     3
# 26         이스라엘     5
# 27          이집트     1
# 28         이탈리아     5
# 29           인도     5
# 30           일본    78
# 31           중국    53
# 32           체코     2
# 33        카자흐스탄     1
# 34          캐나다    11
# 35         콜롬비아     1
# 36           태국     1
# 37           터키     2
# 38           페루     3
# 39          프랑스    44
# ...

# %%
country_counts_action_others[country_counts_action_others.대표국적 == '미국']
# Out:
#    대표국적  영화개수
# 12   미국  1370

# %%
country_counts_action_others[country_counts_action_others.대표국적 == '한국']
# Out:
#    대표국적  영화개수
# 46   한국   359

# %%
country_counts_action_others[country_counts_action_others.대표국적 == '일본']
# Out:
#    대표국적  영화개수
# 35   일본   231

# %%
country_counts_adventure_others[country_counts_adventure_others.대표국적 == '미국']
# Out:
#    대표국적  영화개수
# 12   미국   497

# %%
country_counts_adventure_others[country_counts_adventure_others.대표국적 == '한국']
# Out:
#    대표국적  영화개수
# 41   한국    35

# %%
country_counts_adventure_others[country_counts_adventure_others.대표국적 == '일본']
# Out:
#    대표국적  영화개수
# 30   일본    78

# %%
cc3= country_counts_action_others[country_counts_action_others.영화개수 >= 100]
cc3
# Out:
#    대표국적  영화개수
# 12   미국  1370
# 26   영국   121
# 35   일본   231
# 36   중국   270
# 46   한국   359
# 49   홍콩   206

# %%
cc4= country_counts_adventure_others[country_counts_adventure_others.영화개수 >= 100]
cc4
# Out:
#    대표국적  영화개수
# 12   미국   497

# %%
mv_action_top = mv_2003[mv_2003['장르'].str.contains('액션')]
mv_adventure_top = mv_2003[mv_2003['장르'].str.contains('어드벤처')]

# %%
mv_counts_action_top = mv_action_top.groupby('영화명')['개봉일'].count().reset_index(name='개수')
mv_counts_adventure_top = mv_adventure_top.groupby('영화명')['개봉일'].count().reset_index(name='개수')

# %%
mv_counts_acction_top_sort = mv_counts_action_top.sort_values(by='개수', ascending=False)
mv_counts_adventure_top_sort = mv_counts_adventure_top.sort_values(by='개수', ascending=False)

# %%
mv_action_top_20 = mv_counts_acction_top_sort.iloc[:20,:]
mv_adventure_top_20 = mv_counts_adventure_top_sort.iloc[:20,:]

# %%
index5 = list(mv_action_top_20['영화명'])
index6 = list(mv_adventure_top_20['영화명'])

# %%
mv_action_top_20.plot.bar(x='영화명', y='개수', rot=80, figsize=(10, 5), fontsize=12, color='palevioletred')
plt.title('상영횟수', fontsize=15)
plt.xlabel('영화명', fontsize=12)
plt.ylabel('상영건수', fontsize=12)
# plt.grid(True)
plt.show()

# %%
mv_adventure_top_20.plot.bar(x='영화명', y='개수', rot=80, figsize=(10, 5), fontsize=12, color='hotpink')

plt.title('상영횟수', fontsize=15)
plt.xlabel('영화명', fontsize=12)
plt.ylabel('상영건수', fontsize=12)
# plt.grid(True)
plt.show()

# %%
mv_action_top_20[mv_action_top_20['영화명']==index5]
# Out:
#                    영화명   개수
# 50              다크 나이트  228
# 291              트랜스포머  215
# 282                 테넷  197
# 85       매드 맥스: 분노의 도로  194
# 163                아바타  193
# 230      점박이:한반도의 공룡3D  188
# 140               설국열차  186
# 301           포드 V 페라리  183
# 277            탑건: 매버릭  174
# 90                  명량  171
# 160                신세계  165
# 91                모가디슈  165
# 176                 암살  163
# 190                엑시트  155
# 170                아저씨  155
# 57                덩케르크  149
# 115                베테랑  149
# 184       어벤져스: 인피니티 워  147
# 296              트와일라잇  147
# 237  좋은 놈, 나쁜 놈, 이상한 놈  146

# %%
mv_adventure_top_20[mv_adventure_top_20['영화명']==index6]
# Out:
#                     영화명   개수
# 125               트랜스포머  215
# 71                  알라딘  200
# 8                  겨울왕국  200
# 37        매드 맥스: 분노의 도로  194
# 66                  아바타  193
# 25            라이프 오브 파이  190
# 93        점박이:한반도의 공룡3D  188
# 21             드래곤 길들이기  170
# 75         어벤져스: 인피니티 워  147
# 98    좋은 놈, 나쁜 놈, 이상한 놈  146
# 61        스파이더맨: 노 웨이 홈  144
# 100                주토피아  142
# 138                 해운대  139
# 10                꿀벌대소동  135
# 113              쿵푸팬더 2  134
# 52               블랙 위도우  119
# 31   마다가스카3 : 이번엔 서커스다!  117
# 124            토이 스토리 4  113
# 33                   마션  108
# 88         잃어버린 세계를 찾아서  108

# %%
mv_action_top['기준일'] = pd.to_datetime(mv_action_top['기준일'],format='%Y-%m-%d')
mv_adventure_top['기준일'] = pd.to_datetime(mv_adventure_top['기준일'],format='%Y-%m-%d')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_28084\2962826900.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mv_action_top['기준일'] = pd.to_datetime(mv_action_top['기준일'],format='%Y-%m-%d')
# C:\Users\user\AppData\Local\Temp\ipykernel_28084\2962826900.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mv_adventure_top['기준일'] = pd.to_datetime(mv_adventure_top['기준일'],format='%Y-%m-%d')

# %%
mv_preprocess_action_top = mv_action_top.loc[mv_action_top.groupby(['영화명'])['기준일'].idxmax()]
mv_preprocess_adventure_top = mv_adventure_top.loc[mv_adventure_top.groupby(['영화명'])['기준일'].idxmax()]

# %%
country_counts_action_top = mv_preprocess_action_top.groupby('대표국적')['대표국적'].count()
colors = ['#40E0D0', '#ffc000', '#56B4E9', '#FFFFF0', '#FFEBCD', '#D2691E', '#FFFAF0', '#8fd9b6', '#ff9999']

plt.figure(figsize=(7, 7))

plt.pie(country_counts_action_top, labels=country_counts_action_top.index, autopct='%1.1f%%', colors=colors)
plt.axis('equal')
plt.title('대표국적 비율', fontsize=18)
plt.show()

# %%
country_counts_adventure_top = mv_preprocess_adventure_top.groupby('대표국적')['대표국적'].count()
colors = ['#40E0D0', '#ffc000', '#56B4E9', '#FFFFF0', '#FFEBCD', '#D2691E', '#FFFAF0', '#8fd9b6', '#ff9999']

plt.figure(figsize=(7, 7))
plt.pie(country_counts_adventure_top, labels=country_counts_adventure_top.index, autopct='%1.1f%%', colors=colors)
plt.axis('equal')
plt.title('대표국적 비율', fontsize=18)
plt.show()

# %%
country_counts_action_top_others = mv_preprocess_action_top.groupby('대표국적')['대표국적'].count().reset_index(name='영화개수')
country_counts_action_top_others
# Out:
#   대표국적  영화개수
# 0   독일     1
# 1   미국   197
# 2   영국     1
# 3   중국     4
# 4  프랑스     2
# 5   한국   123

# %%
country_counts_adventure_top_others = mv_preprocess_adventure_top.groupby('대표국적')['대표국적'].count().reset_index(name='영화개수')
country_counts_adventure_top_others
# Out:
#   대표국적  영화개수
# 0   미국   132
# 1  벨기에     1
# 2   영국     1
# 3   일본     1
# 4   한국    11

# %%
country_counts_action_top_others[country_counts_action_top_others.대표국적 == '미국']
# Out:
#   대표국적  영화개수
# 1   미국   197

# %%
country_counts_action_top_others[country_counts_action_top_others.대표국적 == '한국']
# Out:
#   대표국적  영화개수
# 5   한국   123

# %%
country_counts_action_top_others[country_counts_action_top_others.대표국적 == '일본']
# Out:
# Empty DataFrame
# Columns: [대표국적, 영화개수]
# Index: []

# %%
country_counts_adventure_top_others[country_counts_adventure_top_others.대표국적 == '미국']
# Out:
#   대표국적  영화개수
# 0   미국   132

# %%
country_counts_adventure_top_others[country_counts_adventure_top_others.대표국적 == '한국']
# Out:
#   대표국적  영화개수
# 4   한국    11

# %%
country_counts_adventure_top_others[country_counts_adventure_top_others.대표국적 == '일본']
# Out:
#   대표국적  영화개수
# 3   일본     1

# %%
cc5= country_counts_action_top_others[country_counts_action_others.영화개수 >= 100]
cc5
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_28084\1394027261.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   cc5= country_counts_action_top_others[country_counts_action_others.영화개수 >= 100]
# Empty DataFrame
# Columns: [대표국적, 영화개수]
# Index: []

# %%
cc6= country_counts_adventure_top_others[country_counts_adventure_others.영화개수 >= 100]
cc6
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_28084\1004124876.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   cc6= country_counts_adventure_top_others[country_counts_adventure_others.영화개수 >= 100]
# Empty DataFrame
# Columns: [대표국적, 영화개수]
# Index: []

# %%
cc5.sort_values(by=['영화개수'], axis=0)
# Out:
# Empty DataFrame
# Columns: [대표국적, 영화개수]
# Index: []

# %%
cc6.sort_values(by=['영화개수'], axis=0)
# Out:
# Empty DataFrame
# Columns: [대표국적, 영화개수]
# Index: []
