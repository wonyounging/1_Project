# %% [markdown]
# # 액션영화 흥행 비율

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
from matplotlib import font_manager, rc
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['axes.unicode_minus'] = False  # minus 표시
plt.rc('font', family='Malgun Gothic')

# %%
# 이상치 제거 파일 2003-2022 파일 전체 국적 비교

# %%
file_path = "(완)[KOBIS] 박스오피스_일별(2003~2022)_장르_수정.csv"
mv_all = pd.read_csv(file_path)
mv_all
file_path2 = '누적관객수_백만명_이상_766개.csv'
mv_million = pd.read_csv(file_path2)

# %%
mv_million
# Out:
#        순위      영화명         개봉일        등급      장르 대표국적  국적        제작사  \
# 0      34       명량  2014-07-30  15세이상관람가   사극,액션   한국  한국  (주)빅스톤픽쳐스
# 1       7       명량  2014-07-30  15세이상관람가   사극,액션   한국  한국  (주)빅스톤픽쳐스
# 2      22       명량  2014-07-30  15세이상관람가   사극,액션   한국  한국  (주)빅스톤픽쳐스
# 3       9       명량  2014-07-30  15세이상관람가   사극,액션   한국  한국  (주)빅스톤픽쳐스
# 4       9       명량  2014-07-30  15세이상관람가   사극,액션   한국  한국  (주)빅스톤픽쳐스
# ...    ..      ...         ...       ...     ...  ...  ..        ...
# 65789  58  스카이스크래퍼  2018-07-11  12세이상관람가  액션,스릴러   미국  미국        NaN
# 65790  59  스카이스크래퍼  2018-07-11  12세이상관람가  액션,스릴러   미국  미국        NaN
# 65791  49  스카이스크래퍼  2018-07-11  12세이상관람가  액션,스릴러   미국  미국        NaN
# 65792  46  스카이스크래퍼  2018-07-11  12세이상관람가  액션,스릴러   미국  미국        NaN
# 65793  48  스카이스크래퍼  2018-07-11  12세이상관람가  액션,스릴러   미국  미국        NaN
#
#                        배급사        감독  \
# 0                (주)씨제이이엔엠       김한민
# 1                (주)씨제이이엔엠       김한민
# 2                (주)씨제이이엔엠       김한민
# 3                (주)씨제이이엔엠       김한민
# 4                (주)씨제이이엔엠       김한민
# ...                    ...       ...
# 65789  유니버설픽쳐스인터내셔널 코리아(유)  로슨 마샬 터버
# 65790  유니버설픽쳐스인터내셔널 코리아(유)  로슨 마샬 터버
# 65791  유니버설픽쳐스인터내셔널 코리아(유)  로슨 마샬 터버
# 65792  유니버설픽쳐스인터내셔널 코리아(유)  로슨 마샬 터버
# 65793  유니버설픽쳐스인터내셔널 코리아(유)  로슨 마샬 터버
#
#                                                      배우          기준일  \
# 0      최민식,류승룡,조진웅,김명곤,진구,이정현,권율,노민우,이승준,오타니 료헤이,박보검,...  2014-07-20
# 1      최민식,류승룡,조진웅,김명곤,진구,이정현,권율,노민우,이승준,오타니 료헤이,박보검,...  2014-07-21
# 2      최민식,류승룡,조진웅,김명곤,진구,이정현,권율,노민우,이승준,오타니 료헤이,박보검,...  2014-07-22
# 3      최민식,류승룡,조진웅,김명곤,진구,이정현,권율,노민우,이승준,오타니 료헤이,박보검,...  2014-07-23
# 4      최민식,류승룡,조진웅,김명곤,진구,이정현,권율,노민우,이승준,오타니 료헤이,박보검,...  2014-07-24
# ...                                                  ...         ...
# 65789                    드웨인 존슨,파블로 쉬레이버,니브 캠벨,바이런 만,친 한  2018-08-24
# 65790                    드웨인 존슨,파블로 쉬레이버,니브 캠벨,바이런 만,친 한  2018-08-25
# 65791                    드웨인 존슨,파블로 쉬레이버,니브 캠벨,바이런 만,친 한  2018-08-26
# 65792                    드웨인 존슨,파블로 쉬레이버,니브 캠벨,바이런 만,친 한  2018-08-27
# 65793                    드웨인 존슨,파블로 쉬레이버,니브 캠벨,바이런 만,친 한  2018-08-28
#
#             매출액       누적매출액   관객수    누적관객수  스크린수  상영횟수
# 0       1428000     1428000   238      238     1     1
# 1      44016000    45444000  5369     5607    18    28
# 2       4416000    49860000   552     6159    37    38
# 3       6696000    56556000   837     6996     4     4
# 4      14979000    71535000  1890     8886     8    10
# ...         ...         ...   ...      ...   ...   ...
# 65789    496000  8610218718    65  1002606     2     2
# 65790    503000  8610721718    66  1002672     2     2
# 65791    483000  8611204718    65  1002737     2     2
# 65792    457000  8611661718    61  1002798     2     2
# 65793    450000  8612111718    60  1002858     2     2
#
# [65794 rows x 18 columns]

# %%
mv_all
# Out:
#         순위                영화명         개봉일        등급        장르 대표국적  국적  \
# 0        1          동갑내기 과외하기  2003-02-07    12세관람가       코미디   한국  한국
# 1        1         매트릭스3 레볼루션  2003-11-05    15세관람가  SF,액션,범죄   미국  미국
# 2        2             위대한 유산  2003-10-24    15세관람가       코미디   한국  한국
# 3        3                황산벌  2003-10-17    15세관람가       코미디   한국  한국
# 4        4              아이덴티티  2003-10-31    15세관람가    범죄,스릴러   미국  미국
# ...     ..                ...         ...       ...       ...  ...  ..
# 482747  34              애프터 양  2022-06-01     전체관람가    드라마,SF   미국  미국
# 482748  31               더 메뉴  2022-12-07  15세이상관람가       스릴러   미국  미국
# 482749  28  양자경의 더 모든 날 모든 순간  2022-11-23  15세이상관람가    액션,코미디   미국  미국
# 482750  26           캐리와 슈퍼콜라  2023-01-18     전체관람가     애니메이션   한국  한국
# 482751  30                 수라  2023-06-21     전체관람가     다큐멘터리   한국  한국
#
#                     제작사                   배급사               감독  \
# 0            코리아 엔터테인먼트                CJ ENM              김경형
# 1                   NaN         워너브러더스 코리아(주)  릴리 워쇼스키,라나 워쇼스키
# 2                CJ ENM                CJ ENM              오상훈
# 3               (주)씨네월드               (주)씨네월드              이준익
# 4             콜럼비아트라이스타             콜럼비아트라이스타          제임스 맨골드
# ...                 ...                   ...              ...
# 482747              NaN  (주)영화특별시에스엠씨,주식회사 왓챠             코고나다
# 482748              NaN    월트디즈니컴퍼니코리아 유한책임회사           마크 미로드
# 482749              NaN             워터홀컴퍼니(주)   다니엘 콴,다니엘 쉐이너트
# 482750         (주)캐리소프트     롯데컬처웍스(주)롯데엔터테인먼트          오성윤,이춘백
# 482751  스튜디오두마,미디어나무(주)              스튜디오 에이드               황윤
#
#                                                       배우          기준일  \
# 0       김하늘,권상우,공유,김지우,백일섭,김혜옥,김자옥,오승근,이성진,손영민,송병철,신지현...  2003-01-12
# 1                                 키아누 리브스,로렌스 피쉬번,캐리 앤 모스  2003-11-11
# 2       김선아,임창정,최무인,송은정,홍금봉,신성아,김대중,오유진,유순철,신이,모지은,김기천...  2003-11-11
# 3       박중훈,정진영,오지명,김병철,김선아,김윤태,이문식,조대은,김만수,김현두,나수원,조철...  2003-11-11
# 4                                             존 쿠삭,레이 리오타  2003-11-11
# ...                                                   ...         ...
# 482747                                              콜린 파렐  2022-12-31
# 482748     랄프 파인즈,안야 테일러 조이,니콜라스 홀트,자넷 맥티어,주디스 라이트,존 레귀자모  2022-12-31
# 482749                        양자경,스테파니 수,키 호이 콴,제이미 리 커티스  2022-12-31
# 482750        최정윤,엄상현,이다은,원옥화,정주원,이창민,한상태,김지정,강나후,김신비,소경호  2022-12-31
# 482751                                                 황윤  2022-12-31
#
#             매출액      누적매출액  관객수  누적관객수  스크린수  상영횟수
# 0        633500     633500  102    102     1     1
# 1       7676000    7676000  870    870     6    16
# 2       1658000    1658000  177    177     1     3
# 3       1257000    1257000  116    116     1     3
# 4        821000     821000  102    102     1     4
# ...         ...        ...  ...    ...   ...   ...
# 482747   629910  389758300   90  40233     1     1
# 482748  1047000  320680200  107  31360     3     3
# 482749  2703789  291016371  276  27325     7     8
# 482750  3993000    3993000  295    295     1     1
# 482751   770000    3722000  110    481     1     1
#
# [482752 rows x 18 columns]

# %%
mv_all['개봉일'] = pd.to_datetime(mv_all['개봉일'], format='%Y-%m-%d')
mv_all['기준일'] = pd.to_datetime(mv_all['기준일'], format='%Y-%m-%d')
mv_million['개봉일'] = pd.to_datetime(mv_million['개봉일'], format='%Y-%m-%d')
mv_million['기준일'] = pd.to_datetime(mv_million['기준일'], format='%Y-%m-%d')

# %%
# 코드 짜는중...

# %%
mv_all_sorted = mv_all.sort_values(['기준일','순위'], ascending=False)
mv_all_sorted
mv_million_sorted = mv_million.sort_values(['기준일','순위'], ascending=False)
mv_million_sorted
# Out:
#        순위             영화명        개봉일        등급                장르 대표국적  국적  \
# 38477  73  블랙 팬서: 와칸다 포에버 2022-11-09  12세이상관람가       액션,어드벤처,드라마   미국  미국
# 20256  48         너의 이름은. 2017-01-04  12세이상관람가  애니메이션,드라마,멜로/로맨스   일본  일본
# 21280  37            라라랜드 2016-12-07  12세이상관람가    드라마,뮤지컬,멜로/로맨스   미국  미국
# 42563  25          헤어질 결심 2022-06-29  15세이상관람가       미스터리,멜로/로맨스   한국  한국
# 25450   5             올빼미 2022-11-23  15세이상관람가               스릴러   한국  한국
# ...    ..             ...        ...       ...               ...  ...  ..
# 45933   1             실미도 2003-12-24    15세관람가                전쟁   한국  한국
# 45932   1             실미도 2003-12-24    15세관람가                전쟁   한국  한국
# 45931   1             실미도 2003-12-24    15세관람가                전쟁   한국  한국
# 45930   2             실미도 2003-12-24    15세관람가                전쟁   한국  한국
# 45929   5             실미도 2003-12-24    15세관람가                전쟁   한국  한국
#
#                           제작사                  배급사       감독  \
# 38477                     NaN   월트디즈니컴퍼니코리아 유한책임회사  라이언 쿠글러
# 20256                     NaN          플러스엠 엔터테인먼트  신카이 마코토
# 21280                     NaN              판씨네마(주)  데이미언 셔젤
# 42563                    모호필름            (주)씨제이이엔엠      박찬욱
# 25450  (주)씨제스엔터테인먼트,(주)영화사 담담  (주)넥스트엔터테인먼트월드(NEW)      안태진
# ...                       ...                  ...      ...
# 45933               (주)시네마서비스            (주)시네마서비스      강우석
# 45932               (주)시네마서비스            (주)시네마서비스      강우석
# 45931               (주)시네마서비스            (주)시네마서비스      강우석
# 45930               (주)시네마서비스            (주)시네마서비스      강우석
# 45929               (주)시네마서비스            (주)시네마서비스      강우석
#
#                                                      배우         기준일  \
# 38477  레티티아 라이트,루피타 뇽오,다네이 거라이라,마틴 프리먼,다니엘 칼루야,안젤라 바셋... 2022-12-31
# 20256  카미키 류노스케,카미시라이시 모네,나가사와 마사미,이치하라 에수코,유키 아오이,시마... 2022-12-31
# 21280               엠마 스톤,라이언 고슬링,핀 위트록,J.K. 시몬스,로즈마리 드윗 2022-12-31
# 42563  박해일,탕웨이,이정현,고경표,김신영,정영숙,유승목,서현우,정이서,이학주,정소리,신안... 2022-12-31
# 25450  류준열,유해진,최무성,조성하,박명훈,김성철,안은진,조윤서,김상욱,이주원,김예은,정석... 2022-12-31
# ...                                                  ...        ...
# 45933  설경구,안성기,허준호,정재영,임원희,강성진,강신일,이도겸,엄태웅,김강우,이효정,석재... 2003-12-26
# 45932  설경구,안성기,허준호,정재영,임원희,강성진,강신일,이도겸,엄태웅,김강우,이효정,석재... 2003-12-25
# 45931  설경구,안성기,허준호,정재영,임원희,강성진,강신일,이도겸,엄태웅,김강우,이효정,석재... 2003-12-24
# 45930  설경구,안성기,허준호,정재영,임원희,강성진,강신일,이도겸,엄태웅,김강우,이효정,석재... 2003-12-23
# 45929  설경구,안성기,허준호,정재영,임원희,강성진,강신일,이도겸,엄태웅,김강우,이효정,석재... 2003-12-22
#
#              매출액        누적매출액    관객수    누적관객수  스크린수  상영횟수
# 38477     102000  22203069405      8  2105641     1     1
# 20256     295000  30649461917     38  3796229     3     3
# 21280     873000  31079372508     83  3767032     3     3
# 42563    2749310  19642291589    297  1893954     6     9
# 25450  308873990  31769067550  30318  3222767   456   690
# ...          ...          ...    ...      ...   ...   ...
# 45933  104087000    466688000  17411    73988    15    96
# 45932  144917500    362601000  22498    56577    15   103
# 45931  135958000    217683500  21361    34079    15   104
# 45930   71104000     81725500  11123    12718    14    78
# 45929   10621500     10621500   1595     1595     7     7
#
# [65794 rows x 18 columns]

# %%
mv_all_gp = mv_all_sorted.loc[mv_all_sorted.groupby(['영화명', '개봉일'])['기준일'].idxmax()]
mv_all_gp
# Out:
#          순위           영화명        개봉일        등급          장르 대표국적   국적  \
# 409054   29         #살아있다 2020-06-24  15세이상관람가         드라마   한국   한국
# 420077   57        #아이엠히어 2021-01-14  12세이상관람가  멜로/로맨스,코미디  프랑스  프랑스
# 478854   51         #위왓치유 2021-06-03   청소년관람불가       다큐멘터리   기타   기타
# 284094  108        ...ing 2003-11-28    12세관람가  드라마,멜로/로맨스   한국   한국
# 362083   84        0.0MHz 2019-05-29  15세이상관람가      공포(호러)   한국   한국
# ...     ...           ...        ...       ...         ...  ...  ...
# 427292   90     힘내세요, 병헌씨 2013-06-27  15세이상관람가     코미디,드라마   한국   한국
# 379736   15  힘을 내요, 미스터 리 2019-09-11  12세이상관람가     코미디,드라마   한국   한국
# 238564   99    힙스터: 안개의 덫 2015-10-21   청소년관람불가  멜로/로맨스,드라마   한국   한국
# 43736    59            힛쳐 2007-08-01   청소년관람불가   액션,범죄,스릴러   미국   미국
# 288418  101    ＡＶ여배우의 자취방 2017-05-01   청소년관람불가      멜로/로맨스   일본   일본
#
#                       제작사                  배급사                감독  \
# 409054  영화사 집,(주)퍼스펙티브픽쳐스    롯데컬처웍스(주)롯데엔터테인먼트               조일형
# 420077                NaN  (주)넥스트엔터테인먼트월드(NEW)            에릭 라티고
# 478854                NaN                   찬란  바르보라 차르포바,비트 클루삭
# 284094            드림맥스(주)          (주)튜브엔터테인먼트               이언희
# 362083          (주)제이엠컬쳐스            (주)스마일이엔티               유선동
# ...                   ...                  ...               ...
# 427292                NaN               ㈜인디스토리               이병헌
# 379736  (주)용필름,(주)덱스터스튜디오  (주)넥스트엔터테인먼트월드(NEW)               이계벽
# 238564        (주)마부엔터테인먼트          고구마콘텐츠허브(주)               강명진
# 43736                 NaN           (주)씨지브이신도림          데이브 메이어스
# 288418                NaN          (주)도키엔터테인먼트          후지모리 에이지
#
#                                                       배우         기준일  \
# 409054  유아인,박신혜,전배수,고나영,권용채,김경태,김다영,김단비,김라희,김미래,김미래,김윤... 2020-10-28
# 420077  알랭 샤바,배두나,이명자,선종남,김자금,강현중,정윤하,송경의,엄지만,남승화,이지민,... 2021-02-09
# 478854                                                NaN 2022-11-22
# 284094  임수정,김래원,이미숙,김지영,김현수,박혜연,장미,이성경,박소연,김순애,최덕문,김인문... 2017-03-19
# 362083  정은지,이성열,최윤영,신주환,정원창,박명신,남관효,박대희,노혜영,서진석,김대현,신승... 2019-06-28
# ...                                                   ...        ...
# 427292  홍완표,양현민,김영현,허준석,이재광,이창한,정현정,조휘상,강호규,강호규,김수완,황인... 2021-04-21
# 379736  차승원,엄채영,박해준,김혜옥,안길강,전혜빈,류한비,조한철,성지루,김법래,정원중,신현... 2019-12-28
# 238564                            유사라,김동윤,정종우,류아진,박민규,강인화 2015-10-21
# 43736                           숀 빈,소피아 부시,자크리 나이튼,닐 맥도노프 2007-08-13
# 288418                                                NaN 2017-05-01
#
#              매출액        누적매출액   관객수    누적관객수  스크린수  상영횟수
# 409054   2890000  15968219900   289  1903992     2     2
# 420077     82000    136875710    11    16404     6     6
# 478854    288000     16759950    48     1908     1     1
# 284094      5000    217487000     1    34308     1     1
# 362083     84000   1088258860    12   137294     1     1
# ...          ...          ...   ...      ...   ...   ...
# 427292      7000     28862600     1     3980     1     1
# 379736  10950000   9930518906  1095  1181960     5     5
# 238564      5000         5000     1        1     1     1
# 43736       7000    153080000     1    23025     1     1
# 288418      8000         8000     1        1     1     1
#
# [18149 rows x 18 columns]

# %%
mv_all_gp_2003=mv_all_gp[(mv_all_gp['개봉일']>'2003-01-01')&(mv_all_gp['개봉일']<'2008-01-01')]
mv_all_gp_2003
# Out:
#          순위         영화명        개봉일        등급          장르 대표국적   국적  \
# 284094  108      ...ing 2003-11-28    12세관람가  드라마,멜로/로맨스   한국   한국
# 107547   46  007 카지노 로얄 2006-12-21  15세이상관람가          액션   미국   미국
# 66290    43      13 자메티 2007-06-29   청소년관람불가         스릴러  프랑스  프랑스
# 438629   95        13구역 2006-08-24    15세관람가       액션,SF  프랑스  프랑스
# 67216    43        1408 2007-08-01  15세이상관람가  공포(호러),스릴러   미국   미국
# ...     ...         ...        ...       ...         ...  ...  ...
# 1922     18         히달고 2004-03-19    12세관람가          액션   미국   미국
# 420347   51          히든 2006-03-30    15세관람가         스릴러  프랑스  프랑스
# 50290    56         히어로 2007-11-01  12세이상관람가         드라마   일본   일본
# 189673   62         히트맨 2007-11-29   청소년관람불가       액션,범죄   미국   미국
# 43736    59          힛쳐 2007-08-01   청소년관람불가   액션,범죄,스릴러   미국   미국
#
#                        제작사                    배급사         감독  \
# 284094             드림맥스(주)            (주)튜브엔터테인먼트        이언희
# 107547                 NaN    한국소니픽쳐스릴리징브에나비스타영화㈜      마틴 캠벨
# 66290                  NaN              (주)이모션픽처스   겔라 바블루아니
# 438629  까날 플러스,TF1 필름 프로덕션           (주)프라임엔터테인먼트     피에르 모렐
# 67216              디멘션 필름즈          롯데쇼핑㈜롯데엔터테인먼트  미카엘 하프스트롬
# ...                    ...                    ...        ...
# 1922              터치스톤 픽처스    한국소니픽쳐스릴리징브에나비스타영화㈜      조 존스톤
# 420347                 NaN  (주)영화사 안다미로,(주)스폰지이엔티    미카엘 하네케
# 50290                  NaN          롯데쇼핑㈜롯데엔터테인먼트   스즈키 마사유키
# 189673                 NaN          이십세기폭스필름코퍼레이션    자비에르 젠스
# 43736                  NaN             (주)씨지브이신도림   데이브 메이어스
#
#                                                       배우         기준일     매출액  \
# 284094  임수정,김래원,이미숙,김지영,김현수,박혜연,장미,이성경,박소연,김순애,최덕문,김인문... 2017-03-19    5000
# 107547                                           다니엘 크레이그 2010-07-12  -14000
# 66290                                 게오르기 바블루아니,오를레앙 르코앵 2008-08-18   20000
# 438629                                      시릴 라파엘리,데이빗 벨 2021-08-23    2000
# 67216                                      존 쿠삭,사무엘 L. 잭슨 2008-09-02   96000
# ...                                                   ...        ...     ...
# 1922                               줄레이카 로빈슨,비고 모텐슨,오마 샤리프 2004-04-08   40000
# 420347                                    줄리엣 비노쉬,다니엘 오떼유 2021-02-12  137000
# 50290                                      기무라 다쿠야,마츠 다카코 2007-12-05       0
# 189673                                   티모시 올리펀트,더그레이 스콧 2014-01-21  200000
# 43736                           숀 빈,소피아 부시,자크리 나이튼,닐 맥도노프 2007-08-13    7000
#
#              누적매출액  관객수    누적관객수  스크린수  상영횟수
# 284094   217487000    1    34308     1     1
# 107547  6267161700   -2  1012085     1     1
# 66290      6120000    4      913     2     2
# 438629  1416117000    2   222570     2     2
# 67216   1641210000   24   252878     2     3
# ...            ...  ...      ...   ...   ...
# 1922     188771000   10    29703     1     3
# 420347    20288500   23     3004     1     1
# 50290   1581123000    0   245782     1     1
# 189673  1096259000   40   164014     1     1
# 43736    153080000    1    23025     1     1
#
# [1547 rows x 18 columns]

# %%
mv_all_gp_2008=mv_all_gp[(mv_all_gp['개봉일']>'2008-01-01')&(mv_all_gp['개봉일']<'2013-01-01')]
mv_all_gp_2008
# Out:
#         순위                      영화명        개봉일        등급          장르 대표국적  \
# 163198  44                 007 스카이폴 2012-10-26  15세이상관람가          액션   미국
# 153044  72            007 퀀텀 오브 솔러스 2008-11-05  15세이상관람가     액션,어드벤처   미국
# 71657   46  007 퀀텀 오브 솔러스+굿 바이+뱅크 잡 2008-11-05       NaN          기타   기타
# 72919   48  007 퀀텀 오브 솔러스+굿 바이+순정만화 2008-11-27       NaN          기타   기타
# 60385   63                10,000 BC 2008-03-13  15세이상관람가    어드벤처,드라마   미국
# ...     ..                      ...        ...       ...         ...  ...
# 134252  62                       히트 2011-10-13  15세이상관람가  드라마,액션,코미디   한국
# 56317   58               힐링 히스토리-거류 2008-03-06       NaN       다큐멘터리   한국
# 56559   66        힐링 히스토리-돌 속에 갇힌 말 2008-03-06       NaN       다큐멘터리   한국
# 56527   60               힐링 히스토리-숨결 2008-03-06       NaN       다큐멘터리   한국
# 56381   46         힐링 히스토리-이반검열 1+2 2008-03-06       NaN       다큐멘터리   한국
#
#            국적          제작사                       배급사        감독  \
# 163198  미국,영국          NaN  소니픽쳐스릴리징월트디즈니스튜디오스코리아(주)     샘 멘데스
# 153044     미국          NaN       한국소니픽쳐스릴리징브에나비스타영화㈜    마크 포스터
# 71657      기타          NaN                       NaN       NaN
# 72919      기타          NaN                       NaN       NaN
# 60385      미국          NaN             워너브러더스 코리아(주)  롤랜드 에머리히
# ...       ...          ...                       ...       ...
# 134252     한국  (주)부영엔터테인먼트       (주)넥스트엔터테인먼트월드(NEW)       이성한
# 56317      한국          NaN                       NaN       NaN
# 56559      한국          NaN                       NaN       NaN
# 56527      한국          NaN                       NaN       NaN
# 56381      한국          NaN                       NaN       NaN
#
#                                                     배우         기준일     매출액  \
# 163198  다니엘 크레이그,하비에르 바르뎀,주디 덴치,랄프 파인즈,나오미 해리스,베레니스 말로에 2013-02-02  345000
# 153044                         다니엘 크레이그,올가 큐리렌코,매티유 아맬릭 2012-09-06   15000
# 71657                                               NaN 2008-11-12  162000
# 72919                                               NaN 2008-12-01  176000
# 60385                                   스티븐 스트레이트,카밀라 벨 2008-05-05   16000
# ...                                                 ...        ...     ...
# 134252                       박성웅,한재석,정성화,송영창,이하늬,마르코,윤택 2011-11-09   16000
# 56317                                               NaN 2008-03-16   20000
# 56559                                               NaN 2008-03-19    8000
# 56527                                               NaN 2008-03-19   19000
# 56381                                               NaN 2008-03-17   32000
#
#               누적매출액  관객수    누적관객수  스크린수  상영횟수
# 163198  17487818000   69  2376266     1     1
# 153044  14389322000    1  2205160     1     1
# 71657       2422000   14      229     1     1
# 72919       1304000   17      121     1     1
# 60385    7443923500    4  1134364     1     1
# ...             ...  ...      ...   ...   ...
# 134252    783919500    2   110631     1     1
# 56317         47000    4       10     1     1
# 56559         18000    2        4     1     1
# 56527         62000    4       13     1     1
# 56381        188000    7       39     1     1
#
# [2773 rows x 18 columns]

# %%
mv_all_gp_2013=mv_all_gp[(mv_all_gp['개봉일']>'2013-01-01')&(mv_all_gp['개봉일']<'2018-01-01')]
mv_all_gp_2013
# Out:
#          순위               영화명        개봉일        등급              장르 대표국적  \
# 241462   67        007 북경특급 2 2014-05-01  15세이상관람가          코미디,액션   홍콩
# 245155   49           007 스펙터 2015-11-11  15세이상관람가  액션,어드벤처,범죄,스릴러   영국
# 170413   32          009 사이보그 2013-05-09  12세이상관람가           애니메이션   일본
# 174368   80      10 아이템 오어 레스 2013-06-13  15세이상관람가         코미디,드라마   미국
# 235372   95  10,000km(만 킬로미터) 2015-07-16   청소년관람불가      멜로/로맨스,드라마  스페인
# ...     ...               ...        ...       ...             ...  ...
# 293154   39       힐링캠프 : 한 세상 2017-06-22   청소년관람불가          멜로/로맨스   한국
# 296142  107      힐링캠프-한세상 무삭제 2017-07-27   청소년관람불가         드라마,코미디   한국
# 427292   90         힘내세요, 병헌씨 2013-06-27  15세이상관람가         코미디,드라마   한국
# 238564   99        힙스터: 안개의 덫 2015-10-21   청소년관람불가      멜로/로맨스,드라마   한국
# 288418  101        ＡＶ여배우의 자취방 2017-05-01   청소년관람불가          멜로/로맨스   일본
#
#            국적          제작사                  배급사             감독  \
# 241462     홍콩          NaN             (주)케이알씨지        주성치,곡덕소
# 245155  영국,미국          NaN  유니버설픽쳐스인터내셔널 코리아(유)          샘 멘데스
# 170413     일본          NaN  씨너스엔터테인먼트(주),㈜T-JOY        카미야마 켄지
# 174368     미국          NaN        (주)액티버스엔터테인먼트        브래드 실버링
# 235372    스페인          NaN      주식회사 쇼미미디어앤트레이딩  카를로스 마르쿠즈-마르셋
# ...       ...          ...                  ...            ...
# 293154     한국        참프로덕션              THE 픽쳐스            국만중
# 296142     한국      (주)콘텐츠윙              (주)콘텐츠윙            국만중
# 427292     한국          NaN               ㈜인디스토리            이병헌
# 238564     한국  (주)마부엔터테인먼트          고구마콘텐츠허브(주)            강명진
# 288418     일본          NaN          (주)도키엔터테인먼트       후지모리 에이지
#
#                                                       배우         기준일     매출액  \
# 241462                                                주성치 2015-11-23   41000
# 245155                   다니엘 크레이그,레아 세이두,크리스토프 왈츠,모니카 벨루치 2016-01-02  656000
# 170413                                                NaN 2013-05-21  403000
# 174368                                  모건 프리먼,파즈 베가,조나 힐 2013-07-13   82000
# 235372                                  나탈리아 테나,데이비드 베르다거 2015-09-13    9000
# ...                                                   ...        ...     ...
# 293154                             양민우,진달래,윤정희,이상수,이성훈,이슬 2017-06-22  878000
# 296142                                                NaN 2017-07-27    2000
# 427292  홍완표,양현민,김영현,허준석,이재광,이창한,정현정,조휘상,강호규,강호규,김수완,황인... 2021-04-21    7000
# 238564                            유사라,김동윤,정종우,류아진,박민규,강인화 2015-10-21    5000
# 288418                                                NaN 2017-05-01    8000
#
#               누적매출액  관객수    누적관객수  스크린수  상영횟수
# 241462      1010000    7      344     3     3
# 245155  14302132030   82  1820842     1     1
# 170413     13154500   59     1656     9    13
# 174368      8207000   10     1676     2     2
# 235372     10304000    1     1387     1     1
# ...             ...  ...      ...   ...   ...
# 293154       878000  176      176    20    20
# 296142         2000    1        1     1     1
# 427292     28862600    1     3980     1     1
# 238564         5000    1        1     1     1
# 288418         8000    1        1     1     1
#
# [5583 rows x 18 columns]

# %%
mv_all_gp_2018=mv_all_gp[mv_all_gp['개봉일']>'2018-01-01']
mv_all_gp_2018
# Out:
#          순위                영화명        개봉일        등급          장르 대표국적   국적  \
# 409054   29              #살아있다 2020-06-24  15세이상관람가         드라마   한국   한국
# 420077   57             #아이엠히어 2021-01-14  12세이상관람가  멜로/로맨스,코미디  프랑스  프랑스
# 478854   51              #위왓치유 2021-06-03   청소년관람불가       다큐멘터리   기타   기타
# 362083   84             0.0MHz 2019-05-29  15세이상관람가      공포(호러)   한국   한국
# 451191   87      007 노 타임 투 다이 2021-09-29  12세이상관람가          액션   미국   미국
# ...     ...                ...        ...       ...         ...  ...  ...
# 409737  106                히트맨 2020-01-22  15세이상관람가      코미디,액션   한국   한국
# 477051  120      히트맨: 코드네임 버튜소 2022-11-03  15세이상관람가      액션,스릴러   미국   미국
# 427839   86            힐빌리의 노래 2020-11-11   청소년관람불가         드라마   미국   미국
# 423732   57  힘 좋은 시아버지와 착한 며느리 2021-03-18   청소년관람불가  멜로/로맨스,드라마   한국   한국
# 379736   15       힘을 내요, 미스터 리 2019-09-11  12세이상관람가     코미디,드라마   한국   한국
#
#                       제작사                  배급사                감독  \
# 409054  영화사 집,(주)퍼스펙티브픽쳐스    롯데컬처웍스(주)롯데엔터테인먼트               조일형
# 420077                NaN  (주)넥스트엔터테인먼트월드(NEW)            에릭 라티고
# 478854                NaN                   찬란  바르보라 차르포바,비트 클루삭
# 362083          (주)제이엠컬쳐스            (주)스마일이엔티               유선동
# 451191                NaN  유니버설픽쳐스인터내셔널 코리아(유)           캐리 후쿠나가
# ...                   ...                  ...               ...
# 409737         베리굿스튜디오(주)    롯데컬처웍스(주)롯데엔터테인먼트               최원섭
# 477051                NaN             (주)누리픽쳐스               NaN
# 427839                NaN          플러스엠 엔터테인먼트             론 하워드
# 423732           (주)나우콘텐츠             (주)나우콘텐츠               송정규
# 379736  (주)용필름,(주)덱스터스튜디오  (주)넥스트엔터테인먼트월드(NEW)               이계벽
#
#                                                       배우         기준일  \
# 409054  유아인,박신혜,전배수,고나영,권용채,김경태,김다영,김단비,김라희,김미래,김미래,김윤... 2020-10-28
# 420077  알랭 샤바,배두나,이명자,선종남,김자금,강현중,정윤하,송경의,엄지만,남승화,이지민,... 2021-02-09
# 478854                                                NaN 2022-11-22
# 362083  정은지,이성열,최윤영,신주환,정원창,박명신,남관효,박대희,노혜영,서진석,김대현,신승... 2019-06-28
# 451191  다니엘 크레이그,라미 말렉,라샤냐 린치,레아 세이두,벤 위쇼,아나 디 아르마스,나오... 2021-12-27
# ...                                                   ...        ...
# 409737  권상우,정준호,황우슬혜,이이경,이지원,허성태,조운,허동원,이준혁,이중옥,안성봉,주서... 2020-11-04
# 477051                              앤슨 마운트,애비 코니시,안소니 홉킨스 2022-11-03
# 427839         에이미 아담스,글렌 클로즈,가브리엘 바쏘,해일리 베넷,프리다 핀토,보 홉킨스 2021-04-27
# 423732                                                NaN 2021-03-18
# 379736  차승원,엄채영,박해준,김혜옥,안길강,전혜빈,류한비,조한철,성지루,김법래,정원중,신현... 2019-12-28
#
#              매출액        누적매출액   관객수    누적관객수  스크린수  상영횟수
# 409054   2890000  15968219900   289  1903992     2     2
# 420077     82000    136875710    11    16404     6     6
# 478854    288000     16759950    48     1908     1     1
# 362083     84000   1088258860    12   137294     1     1
# 451191     60000  12009884680     3  1229971     1     1
# ...          ...          ...   ...      ...   ...   ...
# 409737         0  20614278000     0  2406232     1     1
# 477051      6000         6000     1        1     1     1
# 427839     46000     34016080     8     4027     1     1
# 423732    100000       100000    20       20     1     1
# 379736  10950000   9930518906  1095  1181960     5     5
#
# [6867 rows x 18 columns]

# %%
mv_million_gp = mv_million_sorted.loc[mv_million_sorted.groupby(['영화명', '개봉일'])['기준일'].idxmax()]
mv_million_gp
# Out:
#         순위            영화명        개봉일        등급              장르 대표국적     국적  \
# 42231   29          #살아있다 2020-06-24  15세이상관람가             드라마   한국     한국
# 57942   87  007 노 타임 투 다이 2021-09-29  12세이상관람가              액션   미국     미국
# 34139   44       007 스카이폴 2012-10-26  15세이상관람가              액션   미국  미국,영국
# 44009   49        007 스펙터 2015-11-11  15세이상관람가  액션,어드벤처,범죄,스릴러   영국  영국,미국
# 65402   46     007 카지노 로얄 2006-12-21  15세이상관람가              액션   미국     미국
# ...    ...            ...        ...       ...             ...  ...    ...
# 31227   93     후궁 : 제왕의 첩 2012-06-06   청소년관람불가       사극,멜로/로맨스   한국     한국
# 50330   47       흡혈형사 나도열 2006-02-09    15세관람가         코미디,드라마   한국     한국
# 6488    83           히말라야 2015-12-16  12세이상관람가             드라마   한국     한국
# 33897  106            히트맨 2020-01-22  15세이상관람가          코미디,액션   한국     한국
# 59546   15   힘을 내요, 미스터 리 2019-09-11  12세이상관람가         코미디,드라마   한국     한국
#
#                       제작사                       배급사       감독  \
# 42231   영화사 집,(주)퍼스펙티브픽쳐스         롯데컬처웍스(주)롯데엔터테인먼트      조일형
# 57942                 NaN       유니버설픽쳐스인터내셔널 코리아(유)  캐리 후쿠나가
# 34139                 NaN  소니픽쳐스릴리징월트디즈니스튜디오스코리아(주)    샘 멘데스
# 44009                 NaN       유니버설픽쳐스인터내셔널 코리아(유)    샘 멘데스
# 65402                 NaN       한국소니픽쳐스릴리징브에나비스타영화㈜    마틴 캠벨
# ...                   ...                       ...      ...
# 31227           (주)황기성 사단             롯데쇼핑㈜롯데엔터테인먼트      김대승
# 50330  영화사청어람(주),(주)에스엠필름                    (주)쇼박스      이시명
# 6488            (주)제이케이필름                 (주)씨제이이엔엠      이석훈
# 33897          베리굿스튜디오(주)         롯데컬처웍스(주)롯데엔터테인먼트      최원섭
# 59546   (주)용필름,(주)덱스터스튜디오       (주)넥스트엔터테인먼트월드(NEW)      이계벽
#
#                                                      배우         기준일       매출액  \
# 42231  유아인,박신혜,전배수,고나영,권용채,김경태,김다영,김단비,김라희,김미래,김미래,김윤... 2020-10-28   2890000
# 57942  다니엘 크레이그,라미 말렉,라샤냐 린치,레아 세이두,벤 위쇼,아나 디 아르마스,나오... 2021-12-27     60000
# 34139    다니엘 크레이그,하비에르 바르뎀,주디 덴치,랄프 파인즈,나오미 해리스,베레니스 말로에 2013-02-02    345000
# 44009                   다니엘 크레이그,레아 세이두,크리스토프 왈츠,모니카 벨루치 2016-01-02    656000
# 65402                                           다니엘 크레이그 2010-07-12    -14000
# ...                                                  ...        ...       ...
# 31227  조여정,김동욱,김민준,조은지,박지영,이경영,박철민,장지민,전주병,정일원,홍수지,신민... 2017-09-27     66000
# 50330  김수로,조여정,김은경,최윤경,이동은,윤신애,백민정,이민아,박영수,김혜연,박은영,나윤... 2006-04-26         0
# 6488   황정민,정우,조성하,김인권,라미란,김원해,이해영,전배수,정유미,유선,한명환,김재준,... 2016-12-04    252000
# 33897  권상우,정준호,황우슬혜,이이경,이지원,허성태,조운,허동원,이준혁,이중옥,안성봉,주서... 2020-11-04         0
# 59546  차승원,엄채영,박해준,김혜옥,안길강,전혜빈,류한비,조한철,성지루,김법래,정원중,신현... 2019-12-28  10950000
#
#              누적매출액   관객수    누적관객수  스크린수  상영횟수
# 42231  15968219900   289  1903992     2     2
# 57942  12009884680     3  1229971     1     1
# 34139  17487818000    69  2376266     1     1
# 44009  14302132030    82  1820842     1     1
# 65402   6267161700    -2  1012085     1     1
# ...            ...   ...      ...   ...   ...
# 31227  19330736000    11  2636385     1     1
# 50330   9693558300     0  1563579     2     4
# 6488   60175363015    52  7759761     1     1
# 33897  20614278000     0  2406232     1     1
# 59546   9930518906  1095  1181960     5     5
#
# [776 rows x 18 columns]

# %%
mv_million_gp_2003=mv_million_gp[(mv_million_gp['개봉일']>'2003-01-01')&(mv_million_gp['개봉일']<'2008-01-01')]
mv_million_gp_2008=mv_million_gp[(mv_million_gp['개봉일']>'2008-01-01')&(mv_million_gp['개봉일']<'2013-01-01')]
mv_million_gp_2013=mv_million_gp[(mv_million_gp['개봉일']>'2013-01-01')&(mv_million_gp['개봉일']<'2018-01-01')]
mv_million_gp_2018=mv_million_gp[mv_million_gp['개봉일']>'2018-01-01']

# %%
# boolean 값 추출
bool_action = mv_all_gp['장르'].str.contains('액션')
bool_thriller = mv_all_gp['장르'].str.contains('스릴러')
bool_adventure= mv_all_gp['장르'].str.contains('어드벤처')
bool_comedy= mv_all_gp['장르'].str.contains('코미디')
bool_drama= mv_all_gp['장르'].str.contains('드라마')
bool_sf= mv_all_gp['장르'].str.contains('SF')
bool_fantasy= mv_all_gp['장르'].str.contains('판타지')

# %%
bool_action2 = mv_million_gp['장르'].str.contains('액션')
bool_thriller2 = mv_million_gp['장르'].str.contains('스릴러')
bool_adventure2= mv_million_gp['장르'].str.contains('어드벤처')
bool_comedy2= mv_million_gp['장르'].str.contains('코미디')
bool_drama2= mv_million_gp['장르'].str.contains('드라마')
bool_sf2= mv_million_gp['장르'].str.contains('SF')
bool_fantasy2= mv_million_gp['장르'].str.contains('판타지')

# %%
act_adv = mv_all_gp[bool_action & bool_adventure]
act_thriller = mv_all_gp[bool_action & bool_thriller]
act_comedy = mv_all_gp[bool_action & bool_comedy]
act_drama = mv_all_gp[bool_action & bool_drama]
act_sf = mv_all_gp[bool_action & bool_sf]
act_fantasy = mv_all_gp[bool_action & bool_fantasy]

# %%
act_adv2 = mv_million_gp[bool_action2 & bool_adventure2]
act_thriller2 = mv_million_gp[bool_action2 & bool_thriller2]
act_comedy2 = mv_million_gp[bool_action2 & bool_comedy2]
act_drama2 = mv_million_gp[bool_action2 & bool_drama2]
act_sf2 = mv_million_gp[bool_action2 & bool_sf2]
act_fantasy2 =  mv_million_gp[bool_action2 & bool_fantasy2]

# %%
mv_action = mv_all_gp[bool_action]
mv_action
# Out:
#          순위                     영화명        개봉일        등급              장르 대표국적  \
# 451191   87           007 노 타임 투 다이 2021-09-29  12세이상관람가              액션   미국
# 241462   67              007 북경특급 2 2014-05-01  15세이상관람가          코미디,액션   홍콩
# 163198   44                007 스카이폴 2012-10-26  15세이상관람가              액션   미국
# 245155   49                 007 스펙터 2015-11-11  15세이상관람가  액션,어드벤처,범죄,스릴러   영국
# 369377   58          007 제2편 : 위기일발 1973-09-21       NaN         액션,어드벤처   영국
# ...     ...                     ...        ...       ...             ...  ...
# 236209   40            히트맨: 에이전트 47 2015-09-03  15세이상관람가       액션,범죄,스릴러   미국
# 477051  120           히트맨: 코드네임 버튜소 2022-11-03  15세이상관람가          액션,스릴러   미국
# 235535   93                  히트스트로크 2015-09-15  15세이상관람가          액션,스릴러   미국
# 267187  108  히틀러 좀비 군단 : 벙커 오브 더 데드 2016-09-21   청소년관람불가    액션,SF,공포(호러)   독일
# 43736    59                      힛쳐 2007-08-01   청소년관람불가       액션,범죄,스릴러   미국
#
#            국적      제작사                       배급사        감독  \
# 451191     미국      NaN       유니버설픽쳐스인터내셔널 코리아(유)   캐리 후쿠나가
# 241462     홍콩      NaN                  (주)케이알씨지   주성치,곡덕소
# 163198  미국,영국      NaN  소니픽쳐스릴리징월트디즈니스튜디오스코리아(주)     샘 멘데스
# 245155  영국,미국      NaN       유니버설픽쳐스인터내셔널 코리아(유)     샘 멘데스
# 369377     영국  이온 프로덕션                       NaN     테렌스 영
# ...       ...      ...                       ...       ...
# 236209     미국      NaN              이십세기폭스코리아(주)   알렉산더 바흐
# 477051     미국      NaN                  (주)누리픽쳐스       NaN
# 235535     미국      NaN               (주)박수엔터테인먼트    에버린 퍼셀
# 267187     독일      NaN               (주)도키엔터테인먼트  마티아스 올로프
# 43736      미국      NaN                (주)씨지브이신도림  데이브 메이어스
#
#                                                       배우         기준일     매출액  \
# 451191  다니엘 크레이그,라미 말렉,라샤냐 린치,레아 세이두,벤 위쇼,아나 디 아르마스,나오... 2021-12-27   60000
# 241462                                                주성치 2015-11-23   41000
# 163198    다니엘 크레이그,하비에르 바르뎀,주디 덴치,랄프 파인즈,나오미 해리스,베레니스 말로에 2013-02-02  345000
# 245155                   다니엘 크레이그,레아 세이두,크리스토프 왈츠,모니카 벨루치 2016-01-02  656000
# 369377                                              숀 코네리 2019-09-21  170000
# ...                                                   ...        ...     ...
# 236209                               루퍼트 프렌드,재커리 퀸토,한나 웨어 2015-09-22  358000
# 477051                              앤슨 마운트,애비 코니시,안소니 홉킨스 2022-11-03    6000
# 235535                          스티븐 도프,메이지 윌리암스,스베트라나 멧키나 2015-09-15   15000
# 267187                                                NaN 2016-09-21    8000
# 43736                           숀 빈,소피아 부시,자크리 나이튼,닐 맥도노프 2007-08-13    7000
#
#               누적매출액  관객수    누적관객수  스크린수  상영횟수
# 451191  12009884680    3  1229971     1     1
# 241462      1010000    7      344     3     3
# 163198  17487818000   69  2376266     1     1
# 245155  14302132030   82  1820842     1     1
# 369377     15113000   85     7448     1     4
# ...             ...  ...      ...   ...   ...
# 236209    502308500   70    64157     1     1
# 477051         6000    1        1     1     1
# 235535        15000    2        2     2     2
# 267187         8000    1        1     1     1
# 43736     153080000    1    23025     1     1
#
# [3029 rows x 18 columns]

# %%
mv_action2 = mv_million_gp[bool_action2]
mv_action2
# Out:
#         순위            영화명        개봉일        등급               장르 대표국적  \
# 57942   87  007 노 타임 투 다이 2021-09-29  12세이상관람가               액션   미국
# 34139   44       007 스카이폴 2012-10-26  15세이상관람가               액션   미국
# 44009   49        007 스펙터 2015-11-11  15세이상관람가   액션,어드벤처,범죄,스릴러   영국
# 65402   46     007 카지노 로얄 2006-12-21  15세이상관람가               액션   미국
# 36596   72  007 퀀텀 오브 솔러스 2008-11-05  15세이상관람가          액션,어드벤처   미국
# ...    ...            ...        ...       ...              ...  ...
# 34024   27  화이: 괴물을 삼킨 아이 2013-10-09   청소년관람불가           액션,스릴러   한국
# 28585   33         황금 나침반 2007-12-18     전체관람가  판타지,드라마,액션,어드벤처   미국
# 35655   31             황해 2010-12-22   청소년관람불가        스릴러,액션,범죄   한국
# 62213   76            회사원 2012-10-11   청소년관람불가           액션,드라마   한국
# 33897  106            히트맨 2020-01-22  15세이상관람가           코미디,액션   한국
#
#              국적                        제작사                       배급사       감독  \
# 57942        미국                        NaN       유니버설픽쳐스인터내셔널 코리아(유)  캐리 후쿠나가
# 34139     미국,영국                        NaN  소니픽쳐스릴리징월트디즈니스튜디오스코리아(주)    샘 멘데스
# 44009     영국,미국                        NaN       유니버설픽쳐스인터내셔널 코리아(유)    샘 멘데스
# 65402        미국                        NaN       한국소니픽쳐스릴리징브에나비스타영화㈜    마틴 캠벨
# 36596        미국                        NaN       한국소니픽쳐스릴리징브에나비스타영화㈜   마크 포스터
# ...         ...                        ...                       ...      ...
# 34024        한국  나우필름(주),파인하우스필름(주),(주)쇼박스                    (주)쇼박스      장준환
# 28585        미국                    뉴라인 시네마             롯데쇼핑㈜롯데엔터테인먼트  크리스 웨이츠
# 35655  한국,미국,중국                      ㈜팝콘필름       (주)쇼박스,이십세기폭스코리아(주)      나홍진
# 62213        한국    영화사심미안(주),(주)쇼박스,(주)51k                    (주)쇼박스      임상윤
# 33897        한국                 베리굿스튜디오(주)         롯데컬처웍스(주)롯데엔터테인먼트      최원섭
#
#                                                      배우         기준일      매출액  \
# 57942  다니엘 크레이그,라미 말렉,라샤냐 린치,레아 세이두,벤 위쇼,아나 디 아르마스,나오... 2021-12-27    60000
# 34139    다니엘 크레이그,하비에르 바르뎀,주디 덴치,랄프 파인즈,나오미 해리스,베레니스 말로에 2013-02-02   345000
# 44009                   다니엘 크레이그,레아 세이두,크리스토프 왈츠,모니카 벨루치 2016-01-02   656000
# 65402                                           다니엘 크레이그 2010-07-12   -14000
# 36596                           다니엘 크레이그,올가 큐리렌코,매티유 아맬릭 2012-09-06    15000
# ...                                                  ...        ...      ...
# 34024  여진구,김윤석,조진웅,장현성,김성균,박해준,임지은,남지현,설우신,이성,이태종,한진,... 2021-08-13  1508000
# 28585                                    다니엘 크레이그,니콜 키드먼 2008-03-04   112000
# 35655  김윤석,하정우,조성하,이철민,박윤호,김기석,박재홍,안서현,박창수,노남석,김기환,백승... 2011-02-01   651000
# 62213  소지섭,이미연,곽도원,배영한,김동준,이경영,한보배,정종열,이학렬,임상윤,곽승원,김봉... 2012-11-18    24000
# 33897  권상우,정준호,황우슬혜,이이경,이지원,허성태,조운,허동원,이준혁,이중옥,안성봉,주서... 2020-11-04        0
#
#              누적매출액  관객수    누적관객수  스크린수  상영횟수
# 57942  12009884680    3  1229971     1     1
# 34139  17487818000   69  2376266     1     1
# 44009  14302132030   82  1820842     1     1
# 65402   6267161700   -2  1012085     1     1
# 36596  14389322000    1  2205160     1     1
# ...            ...  ...      ...   ...   ...
# 34024  17697191795  116  2394603     1     1
# 28585  18336681000   28  2906958     1     1
# 35655  17497165500   84  2260512     1     2
# 62213   8321175000    3  1110523     1     1
# 33897  20614278000    0  2406232     1     1
#
# [329 rows x 18 columns]

# %%
mv_action_add = mv_action[:]
mv_action_add['장르LIST'] = mv_action_add['장르'].apply(lambda x : str(x).split(','))
mv_action_add['장르LIST'] = mv_action_add['장르LIST'].apply(lambda x : sorted(x))
mv_action_add
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_8576\3990135405.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mv_action_add['장르LIST'] = mv_action_add['장르'].apply(lambda x : str(x).split(','))
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_8576\3990135405.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mv_action_add['장르LIST'] = mv_action_add['장르LIST'].apply(lambda x : sorted(x))
#          순위                     영화명        개봉일        등급              장르 대표국적  \
# 451191   87           007 노 타임 투 다이 2021-09-29  12세이상관람가              액션   미국
# 241462   67              007 북경특급 2 2014-05-01  15세이상관람가          코미디,액션   홍콩
# 163198   44                007 스카이폴 2012-10-26  15세이상관람가              액션   미국
# 245155   49                 007 스펙터 2015-11-11  15세이상관람가  액션,어드벤처,범죄,스릴러   영국
# 369377   58          007 제2편 : 위기일발 1973-09-21       NaN         액션,어드벤처   영국
# ...     ...                     ...        ...       ...             ...  ...
# 236209   40            히트맨: 에이전트 47 2015-09-03  15세이상관람가       액션,범죄,스릴러   미국
# 477051  120           히트맨: 코드네임 버튜소 2022-11-03  15세이상관람가          액션,스릴러   미국
# 235535   93                  히트스트로크 2015-09-15  15세이상관람가          액션,스릴러   미국
# 267187  108  히틀러 좀비 군단 : 벙커 오브 더 데드 2016-09-21   청소년관람불가    액션,SF,공포(호러)   독일
# 43736    59                      힛쳐 2007-08-01   청소년관람불가       액션,범죄,스릴러   미국
#
#            국적      제작사                       배급사        감독  \
# 451191     미국      NaN       유니버설픽쳐스인터내셔널 코리아(유)   캐리 후쿠나가
# 241462     홍콩      NaN                  (주)케이알씨지   주성치,곡덕소
# 163198  미국,영국      NaN  소니픽쳐스릴리징월트디즈니스튜디오스코리아(주)     샘 멘데스
# 245155  영국,미국      NaN       유니버설픽쳐스인터내셔널 코리아(유)     샘 멘데스
# 369377     영국  이온 프로덕션                       NaN     테렌스 영
# ...       ...      ...                       ...       ...
# 236209     미국      NaN              이십세기폭스코리아(주)   알렉산더 바흐
# 477051     미국      NaN                  (주)누리픽쳐스       NaN
# 235535     미국      NaN               (주)박수엔터테인먼트    에버린 퍼셀
# 267187     독일      NaN               (주)도키엔터테인먼트  마티아스 올로프
# 43736      미국      NaN                (주)씨지브이신도림  데이브 메이어스
#
#                                                       배우         기준일     매출액  \
# 451191  다니엘 크레이그,라미 말렉,라샤냐 린치,레아 세이두,벤 위쇼,아나 디 아르마스,나오... 2021-12-27   60000
# 241462                                                주성치 2015-11-23   41000
# 163198    다니엘 크레이그,하비에르 바르뎀,주디 덴치,랄프 파인즈,나오미 해리스,베레니스 말로에 2013-02-02  345000
# 245155                   다니엘 크레이그,레아 세이두,크리스토프 왈츠,모니카 벨루치 2016-01-02  656000
# 369377                                              숀 코네리 2019-09-21  170000
# ...                                                   ...        ...     ...
# 236209                               루퍼트 프렌드,재커리 퀸토,한나 웨어 2015-09-22  358000
# 477051                              앤슨 마운트,애비 코니시,안소니 홉킨스 2022-11-03    6000
# 235535                          스티븐 도프,메이지 윌리암스,스베트라나 멧키나 2015-09-15   15000
# 267187                                                NaN 2016-09-21    8000
# 43736                           숀 빈,소피아 부시,자크리 나이튼,닐 맥도노프 2007-08-13    7000
#
#               누적매출액  관객수    누적관객수  스크린수  상영횟수               장르LIST
# 451191  12009884680    3  1229971     1     1                 [액션]
# 241462      1010000    7      344     3     3            [액션, 코미디]
# 163198  17487818000   69  2376266     1     1                 [액션]
# 245155  14302132030   82  1820842     1     1  [범죄, 스릴러, 액션, 어드벤처]
# 369377     15113000   85     7448     1     4           [액션, 어드벤처]
# ...             ...  ...      ...   ...   ...                  ...
# 236209    502308500   70    64157     1     1        [범죄, 스릴러, 액션]
# 477051         6000    1        1     1     1            [스릴러, 액션]
# 235535        15000    2        2     2     2            [스릴러, 액션]
# 267187         8000    1        1     1     1     [SF, 공포(호러), 액션]
# 43736     153080000    1    23025     1     1        [범죄, 스릴러, 액션]
#
# [3029 rows x 19 columns]

# %%
mv_action2_add = mv_action2[:]
mv_action2_add['장르LIST'] = mv_action2_add['장르'].apply(lambda x : str(x).split(','))
mv_action2_add['장르LIST'] = mv_action2_add['장르LIST'].apply(lambda x : sorted(x))
mv_action_add
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_8576\167387324.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mv_action2_add['장르LIST'] = mv_action2_add['장르'].apply(lambda x : str(x).split(','))
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_8576\167387324.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mv_action2_add['장르LIST'] = mv_action2_add['장르LIST'].apply(lambda x : sorted(x))
#          순위                     영화명        개봉일        등급              장르 대표국적  \
# 451191   87           007 노 타임 투 다이 2021-09-29  12세이상관람가              액션   미국
# 241462   67              007 북경특급 2 2014-05-01  15세이상관람가          코미디,액션   홍콩
# 163198   44                007 스카이폴 2012-10-26  15세이상관람가              액션   미국
# 245155   49                 007 스펙터 2015-11-11  15세이상관람가  액션,어드벤처,범죄,스릴러   영국
# 369377   58          007 제2편 : 위기일발 1973-09-21       NaN         액션,어드벤처   영국
# ...     ...                     ...        ...       ...             ...  ...
# 236209   40            히트맨: 에이전트 47 2015-09-03  15세이상관람가       액션,범죄,스릴러   미국
# 477051  120           히트맨: 코드네임 버튜소 2022-11-03  15세이상관람가          액션,스릴러   미국
# 235535   93                  히트스트로크 2015-09-15  15세이상관람가          액션,스릴러   미국
# 267187  108  히틀러 좀비 군단 : 벙커 오브 더 데드 2016-09-21   청소년관람불가    액션,SF,공포(호러)   독일
# 43736    59                      힛쳐 2007-08-01   청소년관람불가       액션,범죄,스릴러   미국
#
#            국적      제작사                       배급사        감독  \
# 451191     미국      NaN       유니버설픽쳐스인터내셔널 코리아(유)   캐리 후쿠나가
# 241462     홍콩      NaN                  (주)케이알씨지   주성치,곡덕소
# 163198  미국,영국      NaN  소니픽쳐스릴리징월트디즈니스튜디오스코리아(주)     샘 멘데스
# 245155  영국,미국      NaN       유니버설픽쳐스인터내셔널 코리아(유)     샘 멘데스
# 369377     영국  이온 프로덕션                       NaN     테렌스 영
# ...       ...      ...                       ...       ...
# 236209     미국      NaN              이십세기폭스코리아(주)   알렉산더 바흐
# 477051     미국      NaN                  (주)누리픽쳐스       NaN
# 235535     미국      NaN               (주)박수엔터테인먼트    에버린 퍼셀
# 267187     독일      NaN               (주)도키엔터테인먼트  마티아스 올로프
# 43736      미국      NaN                (주)씨지브이신도림  데이브 메이어스
#
#                                                       배우         기준일     매출액  \
# 451191  다니엘 크레이그,라미 말렉,라샤냐 린치,레아 세이두,벤 위쇼,아나 디 아르마스,나오... 2021-12-27   60000
# 241462                                                주성치 2015-11-23   41000
# 163198    다니엘 크레이그,하비에르 바르뎀,주디 덴치,랄프 파인즈,나오미 해리스,베레니스 말로에 2013-02-02  345000
# 245155                   다니엘 크레이그,레아 세이두,크리스토프 왈츠,모니카 벨루치 2016-01-02  656000
# 369377                                              숀 코네리 2019-09-21  170000
# ...                                                   ...        ...     ...
# 236209                               루퍼트 프렌드,재커리 퀸토,한나 웨어 2015-09-22  358000
# 477051                              앤슨 마운트,애비 코니시,안소니 홉킨스 2022-11-03    6000
# 235535                          스티븐 도프,메이지 윌리암스,스베트라나 멧키나 2015-09-15   15000
# 267187                                                NaN 2016-09-21    8000
# 43736                           숀 빈,소피아 부시,자크리 나이튼,닐 맥도노프 2007-08-13    7000
#
#               누적매출액  관객수    누적관객수  스크린수  상영횟수               장르LIST
# 451191  12009884680    3  1229971     1     1                 [액션]
# 241462      1010000    7      344     3     3            [액션, 코미디]
# 163198  17487818000   69  2376266     1     1                 [액션]
# 245155  14302132030   82  1820842     1     1  [범죄, 스릴러, 액션, 어드벤처]
# 369377     15113000   85     7448     1     4           [액션, 어드벤처]
# ...             ...  ...      ...   ...   ...                  ...
# 236209    502308500   70    64157     1     1        [범죄, 스릴러, 액션]
# 477051         6000    1        1     1     1            [스릴러, 액션]
# 235535        15000    2        2     2     2            [스릴러, 액션]
# 267187         8000    1        1     1     1     [SF, 공포(호러), 액션]
# 43736     153080000    1    23025     1     1        [범죄, 스릴러, 액션]
#
# [3029 rows x 19 columns]

# %%
mv_action_explode = mv_action_add.explode('장르LIST')
mv_action_explode
# Out:
#          순위                     영화명        개봉일        등급              장르 대표국적  \
# 451191   87           007 노 타임 투 다이 2021-09-29  12세이상관람가              액션   미국
# 241462   67              007 북경특급 2 2014-05-01  15세이상관람가          코미디,액션   홍콩
# 241462   67              007 북경특급 2 2014-05-01  15세이상관람가          코미디,액션   홍콩
# 163198   44                007 스카이폴 2012-10-26  15세이상관람가              액션   미국
# 245155   49                 007 스펙터 2015-11-11  15세이상관람가  액션,어드벤처,범죄,스릴러   영국
# ...     ...                     ...        ...       ...             ...  ...
# 267187  108  히틀러 좀비 군단 : 벙커 오브 더 데드 2016-09-21   청소년관람불가    액션,SF,공포(호러)   독일
# 267187  108  히틀러 좀비 군단 : 벙커 오브 더 데드 2016-09-21   청소년관람불가    액션,SF,공포(호러)   독일
# 43736    59                      힛쳐 2007-08-01   청소년관람불가       액션,범죄,스릴러   미국
# 43736    59                      힛쳐 2007-08-01   청소년관람불가       액션,범죄,스릴러   미국
# 43736    59                      힛쳐 2007-08-01   청소년관람불가       액션,범죄,스릴러   미국
#
#            국적  제작사                       배급사        감독  \
# 451191     미국  NaN       유니버설픽쳐스인터내셔널 코리아(유)   캐리 후쿠나가
# 241462     홍콩  NaN                  (주)케이알씨지   주성치,곡덕소
# 241462     홍콩  NaN                  (주)케이알씨지   주성치,곡덕소
# 163198  미국,영국  NaN  소니픽쳐스릴리징월트디즈니스튜디오스코리아(주)     샘 멘데스
# 245155  영국,미국  NaN       유니버설픽쳐스인터내셔널 코리아(유)     샘 멘데스
# ...       ...  ...                       ...       ...
# 267187     독일  NaN               (주)도키엔터테인먼트  마티아스 올로프
# 267187     독일  NaN               (주)도키엔터테인먼트  마티아스 올로프
# 43736      미국  NaN                (주)씨지브이신도림  데이브 메이어스
# 43736      미국  NaN                (주)씨지브이신도림  데이브 메이어스
# 43736      미국  NaN                (주)씨지브이신도림  데이브 메이어스
#
#                                                       배우         기준일     매출액  \
# 451191  다니엘 크레이그,라미 말렉,라샤냐 린치,레아 세이두,벤 위쇼,아나 디 아르마스,나오... 2021-12-27   60000
# 241462                                                주성치 2015-11-23   41000
# 241462                                                주성치 2015-11-23   41000
# 163198    다니엘 크레이그,하비에르 바르뎀,주디 덴치,랄프 파인즈,나오미 해리스,베레니스 말로에 2013-02-02  345000
# 245155                   다니엘 크레이그,레아 세이두,크리스토프 왈츠,모니카 벨루치 2016-01-02  656000
# ...                                                   ...        ...     ...
# 267187                                                NaN 2016-09-21    8000
# 267187                                                NaN 2016-09-21    8000
# 43736                           숀 빈,소피아 부시,자크리 나이튼,닐 맥도노프 2007-08-13    7000
# 43736                           숀 빈,소피아 부시,자크리 나이튼,닐 맥도노프 2007-08-13    7000
# 43736                           숀 빈,소피아 부시,자크리 나이튼,닐 맥도노프 2007-08-13    7000
#
#               누적매출액  관객수    누적관객수  스크린수  상영횟수  장르LIST
# 451191  12009884680    3  1229971     1     1      액션
# 241462      1010000    7      344     3     3      액션
# 241462      1010000    7      344     3     3     코미디
# 163198  17487818000   69  2376266     1     1      액션
# 245155  14302132030   82  1820842     1     1      범죄
# ...             ...  ...      ...   ...   ...     ...
# 267187         8000    1        1     1     1  공포(호러)
# 267187         8000    1        1     1     1      액션
# 43736     153080000    1    23025     1     1      범죄
# 43736     153080000    1    23025     1     1     스릴러
# 43736     153080000    1    23025     1     1      액션
#
# [6817 rows x 19 columns]

# %%
mv_action2_explode = mv_action2_add.explode('장르LIST')
mv_action2_explode
# Out:
#         순위            영화명        개봉일        등급              장르 대표국적        국적  \
# 57942   87  007 노 타임 투 다이 2021-09-29  12세이상관람가              액션   미국        미국
# 34139   44       007 스카이폴 2012-10-26  15세이상관람가              액션   미국     미국,영국
# 44009   49        007 스펙터 2015-11-11  15세이상관람가  액션,어드벤처,범죄,스릴러   영국     영국,미국
# 44009   49        007 스펙터 2015-11-11  15세이상관람가  액션,어드벤처,범죄,스릴러   영국     영국,미국
# 44009   49        007 스펙터 2015-11-11  15세이상관람가  액션,어드벤처,범죄,스릴러   영국     영국,미국
# ...    ...            ...        ...       ...             ...  ...       ...
# 35655   31             황해 2010-12-22   청소년관람불가       스릴러,액션,범죄   한국  한국,미국,중국
# 62213   76            회사원 2012-10-11   청소년관람불가          액션,드라마   한국        한국
# 62213   76            회사원 2012-10-11   청소년관람불가          액션,드라마   한국        한국
# 33897  106            히트맨 2020-01-22  15세이상관람가          코미디,액션   한국        한국
# 33897  106            히트맨 2020-01-22  15세이상관람가          코미디,액션   한국        한국
#
#                            제작사                       배급사       감독  \
# 57942                      NaN       유니버설픽쳐스인터내셔널 코리아(유)  캐리 후쿠나가
# 34139                      NaN  소니픽쳐스릴리징월트디즈니스튜디오스코리아(주)    샘 멘데스
# 44009                      NaN       유니버설픽쳐스인터내셔널 코리아(유)    샘 멘데스
# 44009                      NaN       유니버설픽쳐스인터내셔널 코리아(유)    샘 멘데스
# 44009                      NaN       유니버설픽쳐스인터내셔널 코리아(유)    샘 멘데스
# ...                        ...                       ...      ...
# 35655                    ㈜팝콘필름       (주)쇼박스,이십세기폭스코리아(주)      나홍진
# 62213  영화사심미안(주),(주)쇼박스,(주)51k                    (주)쇼박스      임상윤
# 62213  영화사심미안(주),(주)쇼박스,(주)51k                    (주)쇼박스      임상윤
# 33897               베리굿스튜디오(주)         롯데컬처웍스(주)롯데엔터테인먼트      최원섭
# 33897               베리굿스튜디오(주)         롯데컬처웍스(주)롯데엔터테인먼트      최원섭
#
#                                                      배우         기준일     매출액  \
# 57942  다니엘 크레이그,라미 말렉,라샤냐 린치,레아 세이두,벤 위쇼,아나 디 아르마스,나오... 2021-12-27   60000
# 34139    다니엘 크레이그,하비에르 바르뎀,주디 덴치,랄프 파인즈,나오미 해리스,베레니스 말로에 2013-02-02  345000
# 44009                   다니엘 크레이그,레아 세이두,크리스토프 왈츠,모니카 벨루치 2016-01-02  656000
# 44009                   다니엘 크레이그,레아 세이두,크리스토프 왈츠,모니카 벨루치 2016-01-02  656000
# 44009                   다니엘 크레이그,레아 세이두,크리스토프 왈츠,모니카 벨루치 2016-01-02  656000
# ...                                                  ...        ...     ...
# 35655  김윤석,하정우,조성하,이철민,박윤호,김기석,박재홍,안서현,박창수,노남석,김기환,백승... 2011-02-01  651000
# 62213  소지섭,이미연,곽도원,배영한,김동준,이경영,한보배,정종열,이학렬,임상윤,곽승원,김봉... 2012-11-18   24000
# 62213  소지섭,이미연,곽도원,배영한,김동준,이경영,한보배,정종열,이학렬,임상윤,곽승원,김봉... 2012-11-18   24000
# 33897  권상우,정준호,황우슬혜,이이경,이지원,허성태,조운,허동원,이준혁,이중옥,안성봉,주서... 2020-11-04       0
# 33897  권상우,정준호,황우슬혜,이이경,이지원,허성태,조운,허동원,이준혁,이중옥,안성봉,주서... 2020-11-04       0
#
#              누적매출액  관객수    누적관객수  스크린수  상영횟수 장르LIST
# 57942  12009884680    3  1229971     1     1     액션
# 34139  17487818000   69  2376266     1     1     액션
# 44009  14302132030   82  1820842     1     1     범죄
# 44009  14302132030   82  1820842     1     1    스릴러
# 44009  14302132030   82  1820842     1     1     액션
# ...            ...  ...      ...   ...   ...    ...
# 35655  17497165500   84  2260512     1     2     액션
# 62213   8321175000    3  1110523     1     1    드라마
# 62213   8321175000    3  1110523     1     1     액션
# 33897  20614278000    0  2406232     1     1     액션
# 33897  20614278000    0  2406232     1     1    코미디
#
# [839 rows x 19 columns]

# %% [markdown]
# ### '장르LIST' 컬럼 기준으로 한글 순서대로 정렬

# %%
action_gerne_ordered = mv_action_explode.sort_values('장르LIST', ascending=True)
action_gerne_ordered
# Out:
#          순위                 영화명        개봉일        등급                   장르  \
# 152845   54       메가샤크VS크로코사우러스 2012-08-30  12세이상관람가                SF,액션
# 207399   35             자이언트 몽키 2014-08-27  12세이상관람가            스릴러,SF,액션
# 49883    50  레지던트 이블 3 - 인류의 멸망 2007-10-18   청소년관람불가     액션,공포(호러),SF,스릴러
# 176705   35               퍼시픽 림 2013-07-11  12세이상관람가           액션,SF,어드벤처
# 165196   66    블러드-C : 더 라스트 다크 2013-02-14   청소년관람불가          애니메이션,SF,액션
# ...     ...                 ...        ...       ...                  ...
# 336984   68               레드 소냐 1985-07-17    연소자관람가          액션,어드벤처,판타지
# 303096   90      몽키킹 VS 구미호 대결전 2017-09-28  15세이상관람가           액션,판타지,코미디
# 423124   99             배트맨 비긴즈 2005-06-24    12세관람가            범죄,액션,판타지
# 213867  110              백여우 전설 2014-11-13  15세이상관람가               판타지,액션
# 442035   80         더 수어사이드 스쿼드 2021-08-04   청소년관람불가  액션,어드벤처,판타지,미스터리,SF
#
#         대표국적               국적              제작사            배급사         감독  \
# 152845    미국               미국              NaN       (주)케이알씨지   크리스토퍼 레이
# 207399    미국               미국              NaN    (유)조이앤컨텐츠그룹   브루스 데이비슨
# 49883    프랑스  프랑스,호주,독일,영국,미국              NaN       ㈜스튜디오이쩜영     러셀 멀케이
# 176705    미국               미국              NaN  워너브러더스 코리아(주)  길예르모 델 토로
# 165196    일본               일본              NaN    골든타이드픽처스(주)  시오타니 나오요시
# ...      ...              ...              ...            ...        ...
# 336984  네덜란드          네덜란드,미국  디노 드 로렌티스 프로덕션즈            NaN   리차드 플레이셔
# 303096    중국               중국              NaN       (주)케이알씨지       메이 천
# 423124    미국               미국      워너 브러더스 픽쳐스  워너브러더스 코리아(주)   크리스토퍼 놀란
# 213867    중국               중국              NaN       (주)케이알씨지        우조양
# 442035    미국               미국              NaN  워너브러더스 코리아(주)      제임스 건
#
#                                                       배우         기준일      매출액  \
# 152845                                            게리 스트레치 2012-09-03    10000
# 207399                                            배리 윌리엄스 2014-09-08   270000
# 49883                                      밀라 요보비치,오데드 페르 2007-11-28    28000
# 176705                           찰리 허냄,론 펄먼,이드리스 엘바,찰리 데이 2013-08-13  1367000
# 165196                                    미즈키 나나,후지와라 케이지 2013-03-03     6000
# ...                                                   ...        ...      ...
# 336984              아놀드 슈왈제네거,브리지트 닐슨,폴 L. 스미스,어니 리에스 주니어 2018-09-26    60000
# 303096                                                NaN 2017-10-11     4000
# 423124                               리암 니슨,크리스찬 베일,마이클 케인 2021-03-12    10000
# 213867                                        종흔동,장지림,혜영홍 2014-11-28    14000
# 442035  마고 로비,이드리스 엘바,존 시나,조엘 킨나만,실베스터 스탤론,비올라 데이비스,제이... 2021-09-28    56000
#
#               누적매출액  관객수    누적관객수  스크린수  상영횟수 장르LIST
# 152845        50000    2       10     1     1     SF
# 207399      4982000   54     1108     1     1     SF
# 49883    3591648000    4   534877     1     1     SF
# 176705  20477374512  194  2539113     6    11     SF
# 165196      2361000    1      326     1     1     SF
# ...             ...  ...      ...   ...   ...    ...
# 336984       420000   30      177     1     1    판타지
# 303096       107000    2       45     2     2    판타지
# 423124   5799228000    2   903202     1     2    판타지
# 213867      1654000    2      408     1     1    판타지
# 442035   4403922930    6   419796     1     1    판타지
#
# [6817 rows x 19 columns]

# %%
action_gerne_ordered2 = mv_action2_explode.sort_values('장르LIST', ascending=True)
action_gerne_ordered2
# Out:
#        순위           영화명        개봉일        등급                       장르 대표국적  \
# 28088  77    엑스맨: 아포칼립스 2016-05-25  12세이상관람가           액션,어드벤처,판타지,SF   미국
# 14139  82            마션 2015-10-08  12세이상관람가               액션,어드벤처,SF   미국
# 22399  46         리얼 스틸 2011-10-12  12세이상관람가                액션,드라마,SF   미국
# 17215  60          아이언맨 2008-04-30  12세이상관람가                SF,드라마,액션   미국
# 55701  68           월ㆍE 2008-08-06     전체관람가  애니메이션,코미디,액션,어드벤처,가족,SF   미국
# ...    ..           ...        ...       ...                      ...  ...
# 44423  69       저스티스 리그 2017-11-15  12세이상관람가           액션,어드벤처,판타지,SF   미국
# 45467  35          콘스탄틴 2005-02-08    15세관람가           드라마,액션,스릴러,판타지   미국
# 45415  99  샹치와 텐 링즈의 전설 2021-09-01  12세이상관람가              액션,어드벤처,판타지   미국
# 6243   78            디워 2007-08-01  12세이상관람가                   액션,판타지   한국
# 11899  53      닥터 스트레인지 2016-10-26  12세이상관람가              액션,어드벤처,판타지   미국
#
#        국적          제작사                              배급사           감독  \
# 28088  미국          NaN                     이십세기폭스코리아(주)      브라이언 싱어
# 14139  미국          NaN  월트디즈니컴퍼니코리아 유한책임회사,이십세기폭스코리아(주)       리들리 스콧
# 22399  미국          NaN              한국소니픽쳐스릴리징브에나비스타영화㈜         숀 레비
# 17215  미국          NaN                           CJ ENM        존 파브로
# 55701  미국          NaN              한국소니픽쳐스릴리징브에나비스타영화㈜      앤드류 스탠튼
# ...    ..          ...                              ...          ...
# 44423  미국          NaN                    워너브러더스 코리아(주)       잭 스나이더
# 45467  미국  워너 브러더스 픽쳐스                    워너브러더스 코리아(주)     프란시스 로렌스
# 45415  미국          NaN               월트디즈니컴퍼니코리아 유한책임회사  데스틴 다니엘 크리튼
# 6243   한국        ㈜영구아트                           (주)쇼박스          심형래
# 11899  미국          NaN                   월트디즈니컴퍼니코리아(주)       스콧 데릭슨
#
#                                                      배우         기준일     매출액  \
# 28088  제임스 맥어보이,마이클 패스벤더,제니퍼 로렌스,오스카 아이삭,니콜라스 홀트,로즈 번... 2016-08-09   80000
# 14139              맷 데이먼,제시카 차스테인,제프 다니엘스,케이트 마라,크리스틴 위그 2020-05-19   32000
# 22399                                               휴 잭맨 2011-12-31  216000
# 17215               로버트 다우니 주니어,테렌스 하워드,제프 브리지스,기네스 팰트로우 2010-05-18   21000
# 55701                                       엘리사 나이트,벤 버트 2020-10-11   12000
# ...                                                  ...        ...     ...
# 44423  벤 애플렉,갤 가돗,제이슨 모모아,레이 피셔,에즈라 밀러,헨리 카빌,J.K. 시몬스... 2018-01-01   15000
# 45467                             키아누 리브스,레이첼 와이즈,시아 라뵈프 2005-03-30   32500
# 45415                                       양조위,아콰피나,양자경 2021-11-16   53000
# 6243                                      브룩스 아만다,베어 제이슨 2008-04-29   24000
# 11899  베네딕트 컴버배치,자라 피티안,레이첼 맥아담스,틸다 스윈튼,매즈 미켈슨,치웨텔 에지... 2018-11-07  590000
#
#              누적매출액  관객수    누적관객수  스크린수  상영횟수 장르LIST
# 28088  24467887950   10  2938818     1     1     SF
# 14139  39702034175    6  4887144     3     3     SF
# 22399  26566677000   27  3579666     1     1     SF
# 17215  27880712500    3  4300365     1     2     SF
# 55701   8305283000   12  1327767     1     1     SF
# ...            ...  ...      ...   ...   ...    ...
# 44423  14629692795    3  1786386     3     3    판타지
# 45467  11164582000    5  1736163     1     1    판타지
# 45415  17715109720    5  1740868     1     1    판타지
# 6243   49340084700    5  7855474     1     1    판타지
# 11899  47490572396   69  5447269     2     2    판타지
#
# [839 rows x 19 columns]

# %%
# 20230525 KKH 시작 - 13:10

# %%
action_genre_country=action_gerne_ordered.groupby(['장르LIST','대표국적'])['대표국적'].agg('count').reset_index(name='전체합')
action_genre_country
# Out:
#     장르LIST   대표국적  전체합
# 0       SF   네덜란드    1
# 1       SF     독일    3
# 2       SF    러시아   12
# 3       SF  말레이시아    1
# 4       SF    모로코    1
# ..     ...    ...  ...
# 335    판타지    핀란드    1
# 336    판타지    필리핀    1
# 337    판타지     한국    9
# 338    판타지     호주    1
# 339    판타지     홍콩   15
#
# [340 rows x 3 columns]

# %%
action_genre_country2=action_gerne_ordered2.groupby(['장르LIST','대표국적'])['대표국적'].agg('count').reset_index(name='흥행합')
action_genre_country2
# Out:
#       장르LIST 대표국적  흥행합
# 0         SF   미국   83
# 1         SF   한국    3
# 2         가족   미국    8
# 3         가족   한국    2
# 4     공포(호러)   독일    1
# 5     공포(호러)   미국    1
# 6     공포(호러)   한국    1
# 7        드라마   미국   31
# 8        드라마   중국    3
# 9        드라마  프랑스    1
# 10       드라마   한국   42
# 11    멜로/로맨스   미국    4
# 12    멜로/로맨스   중국    1
# 13    멜로/로맨스   한국    2
# 14      미스터리   미국    6
# 15      미스터리   한국    2
# 16        범죄   미국   13
# 17        범죄   영국    1
# 18        범죄  프랑스    2
# 19        범죄   한국   33
# 20        사극   미국    1
# 21        사극   중국    2
# 22        사극   한국    8
# 23  서부극(웨스턴)   한국    1
# 24       스릴러   독일    1
# 25       스릴러   미국   43
# 26       스릴러   영국    1
# 27       스릴러  프랑스    1
# 28       스릴러   한국   12
# 29     애니메이션   미국    9
# 30     애니메이션   한국    1
# 31        액션   독일    1
# 32        액션   미국  198
# 33        액션   영국    1
# 34        액션   중국    4
# 35        액션  프랑스    2
# 36        액션   한국  123
# 37      어드벤처   미국   89
# 38      어드벤처   영국    1
# 39      어드벤처   한국    7
# 40        전쟁   미국    3
# 41        전쟁   중국    3
# 42        전쟁   한국    2
# 43       코미디   미국   18
# 44       코미디   한국   23
# 45       판타지   미국   39
# 46       판타지   한국    5

# %%
action_genre_country_ordered =pd.merge(left = action_genre_country , right = action_genre_country2, how = "left", on = ["장르LIST",'대표국적']).fillna(0)
action_genre_country_ordered
# Out:
#     장르LIST   대표국적  전체합  흥행합
# 0       SF   네덜란드    1  0.0
# 1       SF     독일    3  0.0
# 2       SF    러시아   12  0.0
# 3       SF  말레이시아    1  0.0
# 4       SF    모로코    1  0.0
# ..     ...    ...  ...  ...
# 335    판타지    핀란드    1  0.0
# 336    판타지    필리핀    1  0.0
# 337    판타지     한국    9  5.0
# 338    판타지     호주    1  0.0
# 339    판타지     홍콩   15  0.0
#
# [340 rows x 4 columns]

# %%
action_genre_country_ordered2 =pd.merge(left = action_genre_country , right = action_genre_country2, how = "inner", on = ["장르LIST",'대표국적']).fillna(0)
action_genre_country_ordered2
# Out:
#       장르LIST 대표국적   전체합  흥행합
# 0         SF   미국   305   83
# 1         SF   한국     9    3
# 2         가족   미국    24    8
# 3         가족   한국     6    2
# 4     공포(호러)   독일     3    1
# 5     공포(호러)   미국    81    1
# 6     공포(호러)   한국     4    1
# 7        드라마   미국   224   31
# 8        드라마   중국    65    3
# 9        드라마  프랑스    17    1
# 10       드라마   한국   110   42
# 11    멜로/로맨스   미국    24    4
# 12    멜로/로맨스   중국    10    1
# 13    멜로/로맨스   한국    18    2
# 14      미스터리   미국    30    6
# 15      미스터리   한국     7    2
# 16        범죄   미국   216   13
# 17        범죄   영국    20    1
# 18        범죄  프랑스    26    2
# 19        범죄   한국    65   33
# 20        사극   미국     7    1
# 21        사극   중국    19    2
# 22        사극   한국    17    8
# 23  서부극(웨스턴)   한국     2    1
# 24       스릴러   독일     6    1
# 25       스릴러   미국   399   43
# 26       스릴러   영국    31    1
# 27       스릴러  프랑스    30    1
# 28       스릴러   한국    31   12
# 29     애니메이션   미국    36    9
# 30     애니메이션   한국    12    1
# 31        액션   독일    32    1
# 32        액션   미국  1385  198
# 33        액션   영국   122    1
# 34        액션   중국   270    4
# 35        액션  프랑스    81    2
# 36        액션   한국   365  123
# 37      어드벤처   미국   271   89
# 38      어드벤처   영국    22    1
# 39      어드벤처   한국    12    7
# 40        전쟁   미국    71    3
# 41        전쟁   중국    20    3
# 42        전쟁   한국     4    2
# 43       코미디   미국   118   18
# 44       코미디   한국    67   23
# 45       판타지   미국   115   39
# 46       판타지   한국     9    5

# %%
action_genre_country_ordered['흥행률']=action_genre_country_ordered['흥행합']/action_genre_country_ordered['전체합']

# %%
action_genre_country_ordered2['흥행률']=action_genre_country_ordered2['흥행합']/action_genre_country_ordered2['전체합']

# %%
action_genre_country_ordered=action_genre_country_ordered.fillna(0).sort_values(['장르LIST','흥행률'], ascending=False)
action_genre_country_ordered
# Out:
#     장르LIST  대표국적  전체합   흥행합       흥행률
# 337    판타지    한국    9   5.0  0.555556
# 327    판타지    미국  115  39.0  0.339130
# 319    판타지    기타    2   0.0  0.000000
# 320    판타지  네덜란드    1   0.0  0.000000
# 321    판타지  뉴질랜드    3   0.0  0.000000
# ..     ...   ...  ...   ...       ...
# 15      SF    중국    2   0.0  0.000000
# 16      SF   캐나다   20   0.0  0.000000
# 17      SF   프랑스    8   0.0  0.000000
# 19      SF    호주    2   0.0  0.000000
# 20      SF    홍콩    8   0.0  0.000000
#
# [340 rows x 5 columns]

# %%
action_genre_country_ordered2=action_genre_country_ordered2.fillna(0).sort_values(['장르LIST','흥행률'], ascending=False)
action_genre_country_ordered2
# Out:
#       장르LIST 대표국적   전체합  흥행합       흥행률
# 46       판타지   한국     9    5  0.555556
# 45       판타지   미국   115   39  0.339130
# 44       코미디   한국    67   23  0.343284
# 43       코미디   미국   118   18  0.152542
# 42        전쟁   한국     4    2  0.500000
# 41        전쟁   중국    20    3  0.150000
# 40        전쟁   미국    71    3  0.042254
# 39      어드벤처   한국    12    7  0.583333
# 37      어드벤처   미국   271   89  0.328413
# 38      어드벤처   영국    22    1  0.045455
# 36        액션   한국   365  123  0.336986
# 32        액션   미국  1385  198  0.142960
# 31        액션   독일    32    1  0.031250
# 35        액션  프랑스    81    2  0.024691
# 34        액션   중국   270    4  0.014815
# 33        액션   영국   122    1  0.008197
# 29     애니메이션   미국    36    9  0.250000
# 30     애니메이션   한국    12    1  0.083333
# 28       스릴러   한국    31   12  0.387097
# 24       스릴러   독일     6    1  0.166667
# 25       스릴러   미국   399   43  0.107769
# 27       스릴러  프랑스    30    1  0.033333
# 26       스릴러   영국    31    1  0.032258
# 23  서부극(웨스턴)   한국     2    1  0.500000
# 22        사극   한국    17    8  0.470588
# 20        사극   미국     7    1  0.142857
# 21        사극   중국    19    2  0.105263
# 19        범죄   한국    65   33  0.507692
# 18        범죄  프랑스    26    2  0.076923
# 16        범죄   미국   216   13  0.060185
# 17        범죄   영국    20    1  0.050000
# 15      미스터리   한국     7    2  0.285714
# 14      미스터리   미국    30    6  0.200000
# 11    멜로/로맨스   미국    24    4  0.166667
# 13    멜로/로맨스   한국    18    2  0.111111
# 12    멜로/로맨스   중국    10    1  0.100000
# 10       드라마   한국   110   42  0.381818
# 7        드라마   미국   224   31  0.138393
# 9        드라마  프랑스    17    1  0.058824
# 8        드라마   중국    65    3  0.046154
# 4     공포(호러)   독일     3    1  0.333333
# 6     공포(호러)   한국     4    1  0.250000
# 5     공포(호러)   미국    81    1  0.012346
# 2         가족   미국    24    8  0.333333
# 3         가족   한국     6    2  0.333333
# 1         SF   한국     9    3  0.333333
# 0         SF   미국   305   83  0.272131

# %%
action_genre_country_ordered2_Korea = action_genre_country_ordered2[action_genre_country_ordered2['대표국적']=='한국']
action_genre_country_ordered2_Korea=action_genre_country_ordered2_Korea.sort_values(['전체합','흥행률'] ,ascending=False)
action_genre_country_ordered2_Korea
# Out:
#       장르LIST 대표국적  전체합  흥행합       흥행률
# 36        액션   한국  365  123  0.336986
# 10       드라마   한국  110   42  0.381818
# 44       코미디   한국   67   23  0.343284
# 19        범죄   한국   65   33  0.507692
# 28       스릴러   한국   31   12  0.387097
# 13    멜로/로맨스   한국   18    2  0.111111
# 22        사극   한국   17    8  0.470588
# 39      어드벤처   한국   12    7  0.583333
# 30     애니메이션   한국   12    1  0.083333
# 46       판타지   한국    9    5  0.555556
# 1         SF   한국    9    3  0.333333
# 15      미스터리   한국    7    2  0.285714
# 3         가족   한국    6    2  0.333333
# 42        전쟁   한국    4    2  0.500000
# 6     공포(호러)   한국    4    1  0.250000
# 23  서부극(웨스턴)   한국    2    1  0.500000

# %%
action_genre_country_ordered2_Ame = action_genre_country_ordered2[action_genre_country_ordered2['대표국적']=='미국']
action_genre_country_ordered2_Ame=action_genre_country_ordered2_Ame.sort_values(['전체합','흥행률'] ,ascending=False)
action_genre_country_ordered2_Ame
# Out:
#     장르LIST 대표국적   전체합  흥행합       흥행률
# 32      액션   미국  1385  198  0.142960
# 25     스릴러   미국   399   43  0.107769
# 0       SF   미국   305   83  0.272131
# 37    어드벤처   미국   271   89  0.328413
# 7      드라마   미국   224   31  0.138393
# 16      범죄   미국   216   13  0.060185
# 43     코미디   미국   118   18  0.152542
# 45     판타지   미국   115   39  0.339130
# 5   공포(호러)   미국    81    1  0.012346
# 40      전쟁   미국    71    3  0.042254
# 29   애니메이션   미국    36    9  0.250000
# 14    미스터리   미국    30    6  0.200000
# 2       가족   미국    24    8  0.333333
# 11  멜로/로맨스   미국    24    4  0.166667
# 20      사극   미국     7    1  0.142857

# %%
# 20230525 KKH 끝 - 16:00

# %% [markdown]
# 액션 장르별 추출

# %%
# 젠체 장르중 미국이면서,

# %%
mv_action_country_group= action_gerne_ordered.groupby(['영화명','개봉일'])

# %%
action_gerne_ordered.groupby(['영화명','개봉일'])['장르LIST'].count().to_frame()

# %%
action_gerne_ordered2.groupby(['영화명','개봉일'])['장르LIST'].count().to_frame()

# %%
mv_action_genre = mv_action_explode['장르LIST'].to_frame().reset_index(drop=True)
mv_action_genre

# %%
mv_action2_genre = mv_action2_explode['장르LIST'].to_frame().reset_index(drop=True)
mv_action2_genre

# %%
action_gr_cnt = mv_action_genre.value_counts()
action_gr_cnt

# %%
print(type(mv_action_genre.value_counts()))
print(len(mv_action_genre.value_counts()))

# %% [markdown]
# ### 장르 묶인 것으로 분류

# %%
action_classification_cnt = mv_action.groupby(['장르'])['영화명'].count().reset_index(name='액션장르_세부분류').sort_values('액션장르_세부분류', ascending=False)
action_classification_cnt

# %%
action2_classification_cnt = mv_action2.groupby(['장르'])['영화명'].count().reset_index(name='액션장르_세부분류').sort_values('액션장르_세부분류', ascending=False)
action2_classification_cnt

# %%
action_classification_cnt_2 = action_classification_cnt[:]
action_classification_cnt_2['장르LIST'] = action_classification_cnt_2['장르'].apply(lambda x : str(x).split(','))
action_classification_cnt_2

# %%
action2_classification_cnt_2 = action2_classification_cnt[:]
action2_classification_cnt_2['장르LIST'] = action2_classification_cnt_2['장르'].apply(lambda x : str(x).split(','))
action2_classification_cnt_2

# %%
temp = sorted(action_classification_cnt_2['장르LIST'][0])
temp

# %%
temp2 = sorted(action2_classification_cnt_2['장르LIST'][0])
temp2

# %%
action_classification_cnt_3 = action_classification_cnt_2[:]
action_classification_cnt_3['장르LIST'] = action_classification_cnt_3['장르LIST'].apply(lambda x : sorted(x))
action_classification_cnt_3

# %%
action2_classification_cnt_3 = action2_classification_cnt_2[:]
action2_classification_cnt_3['장르LIST'] = action2_classification_cnt_3['장르LIST'].apply(lambda x : sorted(x))
action2_classification_cnt_3

# %%
action_classification_cnt_4 = action_classification_cnt_3[:]
action_classification_cnt_4 = action_classification_cnt_4.drop('장르',axis=1)
action_classification_cnt_4

# %%
action2_classification_cnt_4 = action2_classification_cnt_3[:]
action2_classification_cnt_4 = action2_classification_cnt_4.drop('장르',axis=1)
action2_classification_cnt_4

# %%
action_classification_cnt_5 = action_classification_cnt_4[:]
action_classification_cnt_5['장르LIST']=action_classification_cnt_5['장르LIST'].apply(lambda x: ','.join(map(str, x))).to_frame()
action_classification_cnt_5

# %%
action2_classification_cnt_5 = action2_classification_cnt_4[:]
action2_classification_cnt_5['장르LIST']=action2_classification_cnt_5['장르LIST'].apply(lambda x: ','.join(map(str, x))).to_frame()
action2_classification_cnt_5

# %%
action_classification_cnt_6 = action_classification_cnt_5.groupby('장르LIST')['액션장르_세부분류'].sum().reset_index(name='전체액션영화').sort_values('전체액션영화',ascending=False).set_index('장르LIST')
action_classification_cnt_6

# %%
action2_classification_cnt_6 = action2_classification_cnt_5.groupby('장르LIST')['액션장르_세부분류'].sum().reset_index(name='흥행액션영화').sort_values('흥행액션영화',ascending=False).set_index('장르LIST')
action2_classification_cnt_6

# %%
action_genre_ratio = pd.concat([action_classification_cnt_6,action2_classification_cnt_6],axis=1).fillna(0).astype(int)
action_genre_ratio['흥행률'] = action_genre_ratio['흥행액션영화']/action_genre_ratio['전체액션영화']

# %%
action_genre_ratio2=action_genre_ratio.sort_values(['흥행률'], ascending=False)
action_genre_ratio2

# %%
action_genre_ratio3=action_genre_ratio.sort_values(['흥행액션영화','흥행률'], ascending=False)
action_genre_ratio3[:20]
action_genre2_ratio3=action_genre_ratio3
action_genre_ratio3

# %%
##### 사용하는 표 
action_genre_10= action_genre_ratio3[action_genre_ratio3['전체액션영화']>10]
action_genre_10= action_genre_10.sort_values(['흥행률','흥행액션영화'], ascending=False)
action_genre_10

# %% [markdown]
# ### (액션, 스릴러) 는 (스릴러,액션)과 동일

# %%
mv_action_add = mv_action[:]
mv_action_add['장르LIST'] = mv_action_add['장르'].apply(lambda x : str(x).split(','))
mv_action_add['장르LIST'] = mv_action_add['장르LIST'].apply(lambda x : sorted(x))
mv_action_add['장르LIST'] = mv_action_add['장르LIST'].apply(lambda x: ','.join(map(str, x))).to_frame()
mv_action_add

# %%
mv_action_add2=mv_action_add
mv_action2_add2=mv_action_add

# %%
mv_action2_add = mv_action2[:]
mv_action2_add['장르LIST'] = mv_action2_add['장르'].apply(lambda x : str(x).split(','))
mv_action2_add['장르LIST'] = mv_action2_add['장르LIST'].apply(lambda x : sorted(x))
mv_action2_add['장르LIST'] = mv_action2_add['장르LIST'].apply(lambda x: ','.join(map(str, x))).to_frame()
mv_action2_add

# %%
mv_action_add

# %%
mv_action_add2=mv_action_add2.set_index('장르LIST')

# %%
mv_action2_add2=mv_action2_add2.set_index('장르LIST')

# %%
#합칠것
action_genre2_ratio3

# %%
mv_action_add2=mv_action_add2.join(action_genre2_ratio3)

# %%
mv_action_add2=mv_action_add2.sort_values(['흥행률'], ascending=False)
mv_action_add2

# %%
mv_action2_add2=mv_action2_add2.join(action_genre2_ratio3)

# %%
mv_action2_add2=mv_action_add2.sort_values(['흥행률'], ascending=False)
mv_action2_add2

# %%
액션          3029
스릴러          627
드라마          615
범죄           441
어드벤처         434
SF           430
코미디          304
판타지          243
전쟁           168
애니메이션        134
공포(호러)       122
멜로/로맨스        89
사극            57
미스터리          52
가족            38
서부극(웨스턴)      27
다큐멘터리          3
뮤지컬            2
기타             2

# %%
mv_action_add2=mv_action_add[["장르LIST"]].copy()
mv_action2_add2=mv_action2_add[["장르LIST"]].copy()

# %%
genres = action_gr_cnt.reset_index()['장르LIST'].to_list()
genres = genres[1:]
genres

# %%
genres=['스릴러',
 '드라마',
 '범죄',
 '어드벤처',
 'SF',
 '코미디',
 '판타지',
 '전쟁',
 '애니메이션',
 '공포(호러)',
 '멜로/로맨스',
 '사극',
 '미스터리',
 '가족',
 '서부극(웨스턴)',
 '다큐멘터리',
 '뮤지컬',
 '기타','단독']

# %%
mv_action_add2

# %%
# 장르별 컬럼 만들기
for genre in genres:
    mv_action_add2[genre]=0
    mv_action2_add2[genre]=0

# %%
mv_action_add2.head(1)
mv_action2_add2.head(1)

# %%
for genre in genres:
    mv_action_add2[genre]=mv_action_add2["장르LIST"].apply(lambda x: 1 if genre in x else 0)
    mv_action2_add2[genre]=mv_action2_add2["장르LIST"].apply(lambda x: 1 if genre in x else 0)

# %%
mv_action_add2.head(5)

# %%
mv_action_add2['단독'] = mv_action_add2.sum(axis=1).copy()
mv_action_add2['단독'] = mv_action_add2['단독'].apply(lambda x : 1 if x == 0 else 0)
mv_action_add2

# %%
mv_action2_add2['단독'] = mv_action2_add2.sum(axis=1).copy()
mv_action2_add2['단독'] = mv_action2_add2['단독'].apply(lambda x : 0 if x > 0 else 1)

# %%
mv_action_add2

# %%
mv_action_add2.iloc[:,1:]

# %%
April_genre_df = mv_action_add2.iloc[:,1:]
April_total_genre = April_genre_df.sum(axis=0)
April_total_genre
April_total_genre_fm=pd.DataFrame(April_total_genre)
April_total_genre_fm=April_total_genre_fm.rename(columns={0:'전체액션'})
April_total_genre_fm

# %%
April_genre_df2 = mv_action2_add2.iloc[:,1:]
April_total_genre2 = April_genre_df2.sum(axis=0)
April_total_genre2
April_total_genre2_fm=pd.DataFrame(April_total_genre2)
April_total_genre2_fm=April_total_genre2_fm.rename(columns={0:'흥행액션'})
April_total_genre2_fm

# %%
action_double_genre_ratio = pd.concat([April_total_genre_fm,April_total_genre2_fm],axis=1).fillna(0).astype(int)
action_double_genre_ratio['흥행률'] = April_total_genre2_fm['흥행액션']/April_total_genre_fm['전체액션']
action_double_genre_ratio=action_double_genre_ratio.sort_values(['흥행액션','흥행률'], ascending=False)
action_double_genre_ratio

# %%
# for genre in genres, i in range(0:len(genres)):
#     genre_box=0
#     for k in mv_action_add2_list:
#         if k

# %% [markdown]
# 세부 장르별 국가 흥행비 구하기

# %%
#전체 액션 대표 국적 비율

# %%
#어드벤처 
n_categories = 10  # 표시할 범주 개수

act_mv_counts = act_adv['대표국적'].value_counts()
top_categories = act_mv_adv_counts.head(n_categories)
other_category_count = act_mv_counts.sum() - top_categories.sum()
top_categories['기타'] = other_category_count

labels = top_categories.index.tolist()
colors= sns.color_palette('Set3')
plt.figure(figsize=(10, 10))
patches, _, autotexts = plt.pie(top_categories, labels=labels, colors= colors,autopct=lambda pct: f'{pct:.1f}% ({int(pct * sum(top_categories)/100)})')

plt.title('전체 액션어드벤처영화 대표국적 비율 (상위 {}개)'.format(n_categories))
plt.axis('equal')

plt.show()

# %%
#코미디
n_categories = 10  # 표시할 범주 개수

act_mv_counts = act_comedy['대표국적'].value_counts()
top_categories = act_mv_counts.head(n_categories)
other_category_count = act_mv_counts.sum() - top_categories.sum()
top_categories['기타'] = other_category_count

labels = top_categories.index.tolist()
colors= sns.color_palette('Set3')
plt.figure(figsize=(10, 10))
patches, _, autotexts = plt.pie(top_categories, labels=labels, colors= colors,autopct=lambda pct: f'{pct:.1f}% ({int(pct * sum(top_categories)/100)})')

plt.title('전체 액션코미디영화 대표국적 비율 (상위 {}개)'.format(n_categories))
plt.axis('equal')

plt.show()

# %%
#스릴러
n_categories = 10  # 표시할 범주 개수

act_mv_counts = act_thriller['대표국적'].value_counts()
top_categories = act_mv_counts.head(n_categories)
other_category_count = act_mv_counts.sum() - top_categories.sum()
top_categories['기타'] = other_category_count

labels = top_categories.index.tolist()
colors= sns.color_palette('Set3')
plt.figure(figsize=(10, 10))
patches, _, autotexts = plt.pie(top_categories, labels=labels, colors= colors,autopct=lambda pct: f'{pct:.1f}% ({int(pct * sum(top_categories)/100)})')

plt.title('전체 액션스릴러영화 대표국적 비율 (상위 {}개)'.format(n_categories))
plt.axis('equal')

plt.show()

# %%
#드라마
n_categories = 10  # 표시할 범주 개수

act_mv_counts = act_drama['대표국적'].value_counts()
top_categories = act_mv_counts.head(n_categories)
other_category_count = act_mv_counts.sum() - top_categories.sum()
top_categories['기타'] = other_category_count

labels = top_categories.index.tolist()
colors= sns.color_palette('Set3')
plt.figure(figsize=(10, 10))
patches, _, autotexts = plt.pie(top_categories, labels=labels, colors= colors,autopct=lambda pct: f'{pct:.1f}% ({int(pct * sum(top_categories)/100)})')

plt.title('전체 액션드라마영화 대표국적 비율 (상위 {}개)'.format(n_categories))
plt.axis('equal')

plt.show()

# %%
#sf
n_categories = 10  # 표시할 범주 개수

act_mv_counts = act_sf['대표국적'].value_counts()
top_categories = act_mv_counts.head(n_categories)
other_category_count = act_mv_counts.sum() - top_categories.sum()
top_categories['기타'] = other_category_count

labels = top_categories.index.tolist()
colors= sns.color_palette('Set3')
plt.figure(figsize=(10, 10))
patches, _, autotexts = plt.pie(top_categories, labels=labels, colors= colors,autopct=lambda pct: f'{pct:.1f}% ({int(pct * sum(top_categories)/100)})')

plt.title('전체 액션sf영화 대표국적 비율 (상위 {}개)'.format(n_categories))
plt.axis('equal')

plt.show()

# %%
#판타지 
#sf
n_categories = 10  # 표시할 범주 개수

act_mv_counts = act_fantasy['대표국적'].value_counts()
top_categories = act_mv_counts.head(n_categories)
other_category_count = act_mv_counts.sum() - top_categories.sum()
top_categories['기타'] = other_category_count

labels = top_categories.index.tolist()
colors= sns.color_palette('Set3')
plt.figure(figsize=(10, 10))
patches, _, autotexts = plt.pie(top_categories, labels=labels, colors= colors,autopct=lambda pct: f'{pct:.1f}% ({int(pct * sum(top_categories)/100)})')

plt.title('전체 액션판타지영화 대표국적 비율 (상위 {}개)'.format(n_categories))
plt.axis('equal')

plt.show()

# %%
#흥행 액션 대표 국적 비율

# %%
#흥행 어드벤처
n_categories = 10  # 표시할 범주 개수

act_mv_counts = act_adv2['대표국적'].value_counts()
top_categories = act_mv_counts.head(n_categories)
other_category_count = act_mv_counts.sum() - top_categories.sum()
top_categories['기타'] = other_category_count

labels = top_categories.index.tolist()
colors= sns.color_palette('Set3')
plt.figure(figsize=(10, 10))
patches, _, autotexts = plt.pie(top_categories, labels=labels, colors= colors,autopct=lambda pct: f'{pct:.1f}% ({int(pct * sum(top_categories)/100)})')

plt.title('흥행 액션어드벤처영화 대표국적 비율 상위국가')
plt.axis('equal')

plt.show()

# %%
#흥행코미디
n_categories = 10  # 표시할 범주 개수

act_mv_counts = act_comedy2['대표국적'].value_counts()
top_categories = act_mv_counts.head(n_categories)
other_category_count = act_mv_counts.sum() - top_categories.sum()
top_categories['기타'] = other_category_count

labels = top_categories.index.tolist()
colors= sns.color_palette('Set3')
plt.figure(figsize=(10, 10))
patches, _, autotexts = plt.pie(top_categories, labels=labels, colors= colors,autopct=lambda pct: f'{pct:.1f}% ({int(pct * sum(top_categories)/100)})')

plt.title('흥행 액션코미디영화 대표국적 비율 상위국가')
plt.axis('equal')

plt.show()

# %%
#흥행 스릴러
n_categories = 10  # 표시할 범주 개수

act_mv_counts = act_thriller2['대표국적'].value_counts()
top_categories = act_mv_counts.head(n_categories)
other_category_count = act_mv_counts.sum() - top_categories.sum()
top_categories['기타'] = other_category_count

labels = top_categories.index.tolist()
colors= sns.color_palette('Set3')
plt.figure(figsize=(10, 10))
patches, _, autotexts = plt.pie(top_categories, labels=labels, colors= colors,autopct=lambda pct: f'{pct:.1f}% ({int(pct * sum(top_categories)/100)})')

plt.title('흥행 액션스릴러 대표국적 비율 상위국가')
plt.axis('equal')

plt.show()

# %%
#흥행 드라마
n_categories = 10  # 표시할 범주 개수

act_mv_counts = act_drama2['대표국적'].value_counts()
top_categories = act_mv_counts.head(n_categories)
other_category_count = act_mv_counts.sum() - top_categories.sum()
top_categories['기타'] = other_category_count

labels = top_categories.index.tolist()
colors= sns.color_palette('Set3')
plt.figure(figsize=(10, 10))
patches, _, autotexts = plt.pie(top_categories, labels=labels, colors= colors,autopct=lambda pct: f'{pct:.1f}% ({int(pct * sum(top_categories)/100)})')

plt.title('흥행 액션드라마 대표국적 비율 상위국가')
plt.axis('equal')

plt.show()

# %%
#흥행 액션 sf
n_categories = 10  # 표시할 범주 개수

act_mv_counts = act_sf2['대표국적'].value_counts()
top_categories = act_mv_counts.head(n_categories)
other_category_count = act_mv_counts.sum() - top_categories.sum()
top_categories['기타'] = other_category_count

labels = top_categories.index.tolist()
colors= sns.color_palette('Set3')
plt.figure(figsize=(10, 10))
patches, _, autotexts = plt.pie(top_categories, labels=labels, colors= colors,autopct=lambda pct: f'{pct:.1f}% ({int(pct * sum(top_categories)/100)})')

plt.title('흥행 액션sf 대표국적 비율 상위국가')
plt.axis('equal')

plt.show()

# %%
#흥행 액션 sf
n_categories = 10  # 표시할 범주 개수

act_mv_counts = act_fantasy2['대표국적'].value_counts()
top_categories = act_mv_counts.head(n_categories)
other_category_count = act_mv_counts.sum() - top_categories.sum()
top_categories['기타'] = other_category_count

labels = top_categories.index.tolist()
colors= sns.color_palette('Set3')
plt.figure(figsize=(10, 10))
patches, _, autotexts = plt.pie(top_categories, labels=labels, colors= colors,autopct=lambda pct: f'{pct:.1f}% ({int(pct * sum(top_categories)/100)})')

plt.title('흥행 액션판타지 대표국적 비율 상위국가')
plt.axis('equal')

plt.show()

# %%
act_comedy

# %%
 def get_actor_list(movies, genre):
    movies_genre = movies[movies['장르'].str.contains(genre,na=False)]
    df_actors_v2 = movies_genre[:]
    df_actors_v2['배우List'] = df_actors_v2['배우 '].apply(lambda x : str(x).split(','))
    df_actors_explode_v2 = df_actors_v2.explode(column=['배우List'],ignore_index=True)
    df_group_actor_movie = df_actors_explode_v2.groupby('배우List')['영화명'].apply(list).reset_index(name='영화목록')
    df_group_actor_movie['영화촬영개수'] = df_group_actor_movie['영화목록'].apply(lambda x : len(x))
    df_gp_actor = df_group_actor_movie.sort_values('영화촬영개수', ascending = False)
    return df_gp_actor

# %%
#전체 영화 top 배우

# %%
mv_stars_action_comedy = get_actor_list(mv_all_gp,'코미디')
mv_stars_action_comedy

# %%
mv_stars_action_adv = get_actor_list(mv_all_gp,'어드벤처')
mv_stars_action_adv

# %%
mv_stars_action_thriller = get_actor_list(mv_all_gp,'스릴러')
mv_stars_action_thriller

# %%
mv_stars_action_drama = get_actor_list(mv_all_gp,'드라마')
mv_stars_action_drama

# %%
#흥행 영화 top 배우

# %%
mv_stars_action_comedy2 = get_actor_list(mv_million_gp,'코미디')
mv_stars_action_comedy2

# %%
mv_stars_action_adv2 = get_actor_list(mv_million_gp,'어드벤처')
mv_stars_action_adv2
mv_stars_action_adv2.to_csv('어드벤처 히트배우.csv',encoding='cp949')

# %%
mv_stars_action_thriller2 = get_actor_list(mv_million_gp,'스릴러')
mv_stars_action_thriller2

# %%
mv_stars_action_drama2 = get_actor_list(mv_million_gp,'드라마')
mv_stars_action_drama2

# %% [markdown]
# # 연간 백만 배우 순위 비교

# %%
#코미디
mv_stars_action_comedy2_2003 = get_actor_list(mv_million_gp_2003,'코미디')
mv_stars_action_comedy2_2003.to_csv('코미디 히트배우2003.csv',encoding='cp949')

# %%
mv_stars_action_comedy2_2008 = get_actor_list(mv_million_gp_2008,'코미디')
mv_stars_action_comedy2_2008.to_csv('코미디 히트배우2008.csv',encoding='cp949')

# %%
mv_stars_action_comedy2_2013 = get_actor_list(mv_million_gp_2013,'코미디')
mv_stars_action_comedy2_2013.to_csv('코미디 히트배우2013.csv',encoding='cp949')

# %%
mv_stars_action_comedy2_2018 = get_actor_list(mv_million_gp_2018,'코미디')
mv_stars_action_comedy2_2018.to_csv('코미디 히트배우2018.csv',encoding='cp949')

# %%
#스릴러
mv_stars_action_thriller2_2003 = get_actor_list(mv_million_gp_2003,'스릴러')
mv_stars_action_thriller2_2003

# %%
mv_stars_action_thriller2_2008 = get_actor_list(mv_million_gp_2008,'스릴러')
mv_stars_action_thriller2_2008

# %%
mv_stars_action_thriller2_2013 = get_actor_list(mv_million_gp_2013,'스릴러')
mv_stars_action_thriller2_2013

# %%
mv_stars_action_thriller2_2018 = get_actor_list(mv_million_gp_2018,'스릴러')
mv_stars_action_thriller2_2018

# %%
mv_stars_action_adv2_2003 = get_actor_list(mv_million_gp_2003,'어드벤처')
mv_stars_action_adv2_2003

# %%
mv_stars_action_adv2_2008 = get_actor_list(mv_million_gp_2008,'어드벤처')
mv_stars_action_adv2_2008

# %%
mv_stars_action_adv2_2013 = get_actor_list(mv_million_gp_2013,'어드벤처')
mv_stars_action_adv2_2013

# %%
mv_stars_action_adv2_2018 = get_actor_list(mv_million_gp_2018,'어드벤처')
mv_stars_action_adv2_2018

# %%
mv_stars_action_drama2_2003 = get_actor_list(mv_million_gp_2003,'드라마')
mv_stars_action_drama2_2003

# %%
mv_stars_action_drama2_2008 = get_actor_list(mv_million_gp_2008,'드라마')
mv_stars_action_drama2_2008

# %%
mv_stars_action_drama2_2013 = get_actor_list(mv_million_gp_2013,'드라마')
mv_stars_action_drama2_2013

# %%
mv_stars_action_drama2_2018 = get_actor_list(mv_million_gp_2018,'드라마')
mv_stars_action_drama2_2018
