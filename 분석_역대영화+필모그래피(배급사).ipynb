# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import matplotlib.cm as cm
mpl.rcParams['font.family'] ='Malgun Gothic'
mpl.rcParams['axes.unicode_minus'] =False

plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

# %%
data200 = pd.read_csv('./역대영화+필모그래피.csv')
data200
# Out:
#               영화명                  배급사         개봉일          매출액       관객수  \
# 0            1987            (주)씨제이이엔엠  2017-12-27  58170216145   7232452
# 1            2012  한국소니픽쳐스릴리징브에나비스타영화㈜  2009-11-12  38941723000   5397597
# 2          7급 공무원        롯데쇼핑㈜롯데엔터테인먼트  2009-04-22  26380710000   4039891
# 3         7번방의 선물  (주)넥스트엔터테인먼트월드(NEW)  2013-01-23  91437368170  12812144
# 4        82년생 김지영    롯데컬처웍스(주)롯데엔터테인먼트  2019-10-23  30306859310   3679162
# ..            ...                  ...         ...          ...       ...
# 195  해적: 바다로 간 산적        롯데쇼핑㈜롯데엔터테인먼트  2014-08-06  66372140706   8666208
# 196            헌트          플러스엠 엔터테인먼트  2022-08-10  44601068153   4352420
# 197  혹성탈출: 반격의 서막         이십세기폭스코리아(주)  2014-07-10  31514053095   4002560
# 198        화려한 휴가               CJ ENM  2007-07-25  44098824600   6855433
# 199          히말라야            (주)씨제이이엔엠  2015-12-16  60175363015   7759761
#
#        제작연도             장르
# 0    2017.0            드라마
# ...

# %% [markdown]
# # 역대 영화 배급사 빈도

# %%
dist_cnt = data200['배급사'].value_counts()
dist_cnt
# Out:
# (주)씨제이이엔엠                                      36
# (주)쇼박스                                         32
# (주)넥스트엔터테인먼트월드(NEW)                            17
# CJ ENM                                         15
# 월트디즈니컴퍼니코리아 유한책임회사                             13
# 롯데쇼핑㈜롯데엔터테인먼트                                  13
# 워너브러더스 코리아(주)                                  12
# 유니버설픽쳐스인터내셔널 코리아(유)                             8
# 롯데컬처웍스(주)롯데엔터테인먼트                               7
# 이십세기폭스코리아(주)                                    7
# 한국소니픽쳐스릴리징브에나비스타영화㈜                             5
# 소니픽쳐스엔터테인먼트코리아주식회사극장배급지점                        4
# 월트디즈니컴퍼니코리아(주)                                  3
# 소니픽쳐스릴리징월트디즈니스튜디오스코리아(주)                        3
# 월트디즈니컴퍼니코리아 유한책임회사,이십세기폭스코리아(주)                 2
# UIP코리아                                          2
# 플러스엠 엔터테인먼트                                     2
# 월트디즈니컴퍼니코리아 유한책임회사,월트디즈니컴퍼니코리아(주)               2
# 판씨네마(주)                                         2
# ...

# %%
data200["배급사"].value_counts().sort_values().plot.barh()
plt.title('역대 영화 배급사 빈도수')
plt.show()

# %% [markdown]
# # 역대 영화 장르 분포

# %%
dra = 0 # 드라마
sf = 0 # SF
act = 0 # 액션
adv = 0 # 어드벤처
com = 0 # 코미디
cri = 0 # 범죄
mel = 0 # 멜로/로맨스
fam = 0 # 가족
mus = 0 # 뮤지컬
fan = 0 # 판타지
ani = 0 # 애니메이션
mys = 0 # 미스터리
thr = 0 # 스릴러
his = 0 # 사극
doc = 0 # 다큐멘터리
war = 0 # 전쟁
hor = 0 # 공포
etc = 0 # 기타(기타, 서부극)

for i in range(200):
    try:
        detail_genre = data200['장르'][i].split(',')
        for j in range(len(detail_genre)):
            if detail_genre[j] == '드라마':
                dra = dra + 1
            elif detail_genre[j] == 'SF':
                sf = sf + 1
            elif detail_genre[j] == '액션':
                act = act + 1
            elif detail_genre[j] == '어드벤처':
                adv = adv + 1
            elif detail_genre[j] == '코미디':
                com = com + 1
            elif detail_genre[j] == '범죄':
                cri = cri + 1
            elif detail_genre[j] == '멜로/로맨스':
                mel = mel + 1
            elif detail_genre[j] == '가족':
                fam = fam + 1
            elif detail_genre[j] == '뮤지컬':
                mus = mus + 1
            elif detail_genre[j] == '판타지':
                fan = fan + 1
            elif detail_genre[j] == '애니메이션':
                ani = ani + 1
            elif detail_genre[j] == '미스터리':
                mys = mys + 1
            elif detail_genre[j] == '스릴러':
                thr = thr + 1
            elif detail_genre[j] == '사극':
                his = his + 1
            elif detail_genre[j] == '다큐멘터리':
                doc = doc + 1
            elif detail_genre[j] == '전쟁':
                war = war + 1
            elif detail_genre[j] == '공포(호러)':
                hor = hor + 1
            else:
                print(detail_genre[j])
                etc = etc + 1
    except:
        continue
print(dra,sf,act,adv,com,cri,mel,fam,mus,fan,ani,mys,thr,his,doc,war,hor,etc)

genre_freq = pd.DataFrame([[dra, sf, act, adv, com, cri, mel, fam, mus, fan, ani, mys, thr, his, doc, war, hor, etc]],
                          columns = ['드라마', 'SF', '액션', '어드벤처', '코미디', '범죄', '멜로/로맨스',
                                    '가족', '뮤지컬', '판타지', '애니메이션', '미스터리', '스릴러', '사극',
                                    '다큐멘터리', '전쟁', '공포(호러)', '기타'],
                         index = ['빈도수'])
# Out:
# 기타
# 서부극(웨스턴)
# 80 38 110 49 33 22 9 7 3 23 11 5 20 14 1 3 2 2

# %%
genre_freq
# Out:
#      드라마  SF   액션  어드벤처  코미디  범죄  멜로/로맨스  가족  뮤지컬  판타지  애니메이션  미스터리  스릴러  사극  \
# 빈도수   80  38  110    49   33  22       9   7    3   23     11     5   20  14
#
#      다큐멘터리  전쟁  공포(호러)  기타
# 빈도수      1   3       2   2

# %%
# 시각화
genre_freq.columns
# Out:
# Index(['드라마', 'SF', '액션', '어드벤처', '코미디', '범죄', '멜로/로맨스', '가족', '뮤지컬', '판타지',
#        '애니메이션', '미스터리', '스릴러', '사극', '다큐멘터리', '전쟁', '공포(호러)', '기타'],
#       dtype='object')

# %% [markdown]
# # 상위 13개 장르 이외 기타 처리

# %%
dra = 0 # 드라마
sf = 0 # SF
act = 0 # 액션
adv = 0 # 어드벤처
com = 0 # 코미디
cri = 0 # 범죄
mel = 0 # 멜로/로맨스
fam = 0 # 가족
mus = 0 # 뮤지컬
fan = 0 # 판타지
ani = 0 # 애니메이션
mys = 0 # 미스터리
thr = 0 # 스릴러
his = 0 # 사극
doc = 0 # 다큐멘터리
war = 0 # 전쟁
hor = 0 # 공포
etc = 0 # 기타(기타, 서부극)

for i in range(200):
    try:
        detail_genre = data200['장르'][i].split(',')
        for j in range(len(detail_genre)):
            if detail_genre[j] == '드라마':
                dra = dra + 1
            elif detail_genre[j] == 'SF':
                sf = sf + 1
            elif detail_genre[j] == '액션':
                act = act + 1
            elif detail_genre[j] == '어드벤처':
                adv = adv + 1
            elif detail_genre[j] == '코미디':
                com = com + 1
            elif detail_genre[j] == '범죄':
                cri = cri + 1
            elif detail_genre[j] == '멜로/로맨스':
                mel = mel + 1
            elif detail_genre[j] == '가족':
                fam = fam + 1
            elif detail_genre[j] == '판타지':
                fan = fan + 1
            elif detail_genre[j] == '애니메이션':
                ani = ani + 1
            elif detail_genre[j] == '스릴러':
                thr = thr + 1
            elif detail_genre[j] == '사극':
                his = his + 1
            else:
                print(detail_genre[j])
                etc = etc + 1
    except:
        continue
print(dra,sf,act,adv,com,cri,mel,fam,mus,fan,ani,mys,thr,his,doc,war,hor,etc)

genre_freq = pd.DataFrame([[dra, sf, act, adv, com, cri, mel, fam, fan, ani, thr, his, etc]],
                          columns = ['드라마', 'SF', '액션', '어드벤처', '코미디', '범죄', '멜로/로맨스',
                                    '가족', '판타지', '애니메이션', '스릴러', '사극', '기타'],
                         index = ['빈도수'])
# Out:
# 미스터리
# 뮤지컬
# 미스터리
# 다큐멘터리
# 미스터리
# 기타
# 뮤지컬
# 뮤지컬
# 전쟁
# 공포(호러)
# 전쟁
# 미스터리
# 전쟁
# 서부극(웨스턴)
# 미스터리
# 공포(호러)
# 80 38 110 49 33 22 9 7 0 23 11 0 20 14 0 0 0 16

# %%
labels = genre_freq.columns.tolist()
ratio = genre_freq.values.flatten().tolist()

# 비율순으로 정렬
sorted_ratio, sorted_labels = zip(*sorted(zip(ratio, labels), reverse=True))

plt.figure(figsize=(10, 10))

plt.pie(sorted_ratio, labels=sorted_labels, autopct='%.0f%%', startangle=90, radius=0.9)
plt.title('역대 영화 장르 분포')
plt.legend(sorted_labels, loc='best', fontsize=6)

plt.show()

# %% [markdown]
# # 역대 관객수

# %%
# 관객수 내림차순
attendance_rank = data.sort_values('관객수', ascending=False)
attendance_rank
# Out:
#              영화명                  배급사         개봉일           매출액       관객수  \
# 64            명량            (주)씨제이이엔엠  2014-07-30  135758658810  17615919
# 28          극한직업            (주)씨제이이엔엠  2019-01-23  139655543516  16266338
# 105    신과함께-죄와 벌        롯데쇼핑㈜롯데엔터테인먼트  2017-12-20  115727528087  14414658
# 24          국제시장            (주)씨제이이엔엠  2014-12-17  110947621230  14264478
# 129   어벤져스: 엔드게임   월트디즈니컴퍼니코리아 유한책임회사  2019-04-24  122492181020  13977602
# ..           ...                  ...         ...           ...       ...
# 192  해리 포터와 불의 잔        워너브러더스 코리아(주)  2005-12-01   22097731900   3499257
# 94        비긴 어게인              판씨네마(주)  2014-08-13   27433947031   3479444
# 179           태풍               CJ ENM  2005-12-14   22209675300   3471150
# 174           킹콩               UIP코리아  2005-12-14   21476688172   3470059
# 89        부러진 화살  (주)넥스트엔터테인먼트월드(NEW)  2012-01-18   25938096000   3460212
#
#        제작연도        장르
# 64   2013.0     사극,액션
# 28   2018.0       코미디
# ...

# %%
# 역대 관객수 top 50
attendance_rank_50 = attendance_rank[:50]
attendance_rank_50
# Out:
#                   영화명                                배급사         개봉일  \
# 64                 명량                          (주)씨제이이엔엠  2014-07-30
# 28               극한직업                          (주)씨제이이엔엠  2019-01-23
# 105         신과함께-죄와 벌                      롯데쇼핑㈜롯데엔터테인먼트  2017-12-20
# 24               국제시장                          (주)씨제이이엔엠  2014-12-17
# 129        어벤져스: 엔드게임                 월트디즈니컴퍼니코리아 유한책임회사  2019-04-24
# 13             겨울왕국 2                 월트디즈니컴퍼니코리아 유한책임회사  2019-11-21
# 85                베테랑                          (주)씨제이이엔엠  2015-08-05
# 113               아바타          주식회사 해리슨앤컴퍼니,이십세기폭스코리아(주)  2009-12-17
# 51                도둑들                             (주)쇼박스  2012-07-25
# 3             7번방의 선물                (주)넥스트엔터테인먼트월드(NEW)  2013-01-23
# 121               알라딘                 월트디즈니컴퍼니코리아 유한책임회사  2019-05-23
# 122                암살                             (주)쇼박스  2015-07-22
# 81              범죄도시2        주식회사 에이비오엔터테인먼트,플러스엠 엔터테인먼트  2022-05-18
# ...

# %%
# 매출액 내림차순
sales_rank = data.sort_values('매출액', ascending=False)
sales_rank
# Out:
#                   영화명                          배급사         개봉일           매출액  \
# 28               극한직업                    (주)씨제이이엔엠  2019-01-23  139655543516
# 114         아바타: 물의 길           월트디즈니컴퍼니코리아 유한책임회사  2022-12-14  137647702899
# 64                 명량                    (주)씨제이이엔엠  2014-07-30  135758658810
# 81              범죄도시2  주식회사 에이비오엔터테인먼트,플러스엠 엔터테인먼트  2022-05-18  131298796478
# 113               아바타    주식회사 해리슨앤컴퍼니,이십세기폭스코리아(주)  2009-12-17  125304346000
# ..                ...                          ...         ...           ...
# 163  캐리비안의 해적 : 망자의 함               브에나비스타인터내셔널코리아  2006-07-06   23832939000
# 191    해리 포터와 불사조 기사단                워너브러더스 코리아(주)  2007-07-11   23010956770
# 179                태풍                       CJ ENM  2005-12-14   22209675300
# 192       해리 포터와 불의 잔                워너브러더스 코리아(주)  2005-12-01   22097731900
# 174                킹콩                       UIP코리아  2005-12-14   21476688172
#
#           관객수    제작연도               장르
# ...

# %%
# 역대 매출액 top 50
sales_rank_50 = sales_rank[:50]
sales_rank_50
# Out:
#                      영화명                                     배급사         개봉일  \
# 28                  극한직업                               (주)씨제이이엔엠  2019-01-23
# 114            아바타: 물의 길                      월트디즈니컴퍼니코리아 유한책임회사  2022-12-14
# 64                    명량                               (주)씨제이이엔엠  2014-07-30
# 81                 범죄도시2             주식회사 에이비오엔터테인먼트,플러스엠 엔터테인먼트  2022-05-18
# 113                  아바타               주식회사 해리슨앤컴퍼니,이십세기폭스코리아(주)  2009-12-17
# 129           어벤져스: 엔드게임                      월트디즈니컴퍼니코리아 유한책임회사  2019-04-24
# 105            신과함께-죄와 벌                           롯데쇼핑㈜롯데엔터테인먼트  2017-12-20
# 13                겨울왕국 2                      월트디즈니컴퍼니코리아 유한책임회사  2019-11-21
# 24                  국제시장                               (주)씨제이이엔엠  2014-12-17
# 121                  알라딘                      월트디즈니컴퍼니코리아 유한책임회사  2019-05-23
# 85                   베테랑                               (주)씨제이이엔엠  2015-08-05
# ...

# %%
attendance_rank_50
# Out:
#                   영화명                                배급사         개봉일  \
# 64                 명량                          (주)씨제이이엔엠  2014-07-30
# 28               극한직업                          (주)씨제이이엔엠  2019-01-23
# 105         신과함께-죄와 벌                      롯데쇼핑㈜롯데엔터테인먼트  2017-12-20
# 24               국제시장                          (주)씨제이이엔엠  2014-12-17
# 129        어벤져스: 엔드게임                 월트디즈니컴퍼니코리아 유한책임회사  2019-04-24
# 13             겨울왕국 2                 월트디즈니컴퍼니코리아 유한책임회사  2019-11-21
# 85                베테랑                          (주)씨제이이엔엠  2015-08-05
# 113               아바타          주식회사 해리슨앤컴퍼니,이십세기폭스코리아(주)  2009-12-17
# 51                도둑들                             (주)쇼박스  2012-07-25
# 3             7번방의 선물                (주)넥스트엔터테인먼트월드(NEW)  2013-01-23
# 121               알라딘                 월트디즈니컴퍼니코리아 유한책임회사  2019-05-23
# 122                암살                             (주)쇼박스  2015-07-22
# 81              범죄도시2        주식회사 에이비오엔터테인먼트,플러스엠 엔터테인먼트  2022-05-18
# ...

# %%
mv_name = attendance_rank_50['영화명']
attendance_val = attendance_rank_50['관객수']
sales_val = attendance_rank_50['매출액']

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 13))
fig.set_facecolor('white')

# 관객수 시각화
ax1.bar(mv_name, attendance_val)
ax1.set_ylabel('관객수')

# 매출액 시각화
ax2.bar(mv_name, sales_val)
ax2.set_ylabel('매출액')

# x축 라벨 설정
plt.setp(ax1.get_xticklabels(), rotation=45, ha='right', fontsize=10)
plt.setp(ax2.get_xticklabels(), rotation=45, ha='right', fontsize=10)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 개봉일에서 개봉년도 추가

# %%
attendance_rank_50['개봉년도'] = pd.DatetimeIndex(attendance_rank_50['개봉일']).year
attendance_rank_50['개봉년도'] = attendance_rank_50['개봉년도'].astype(int)
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_9500\1461534147.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   attendance_rank_50['개봉년도'] = pd.DatetimeIndex(attendance_rank_50['개봉일']).year
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_9500\1461534147.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   attendance_rank_50['개봉년도'] = attendance_rank_50['개봉년도'].astype(int)

# %%
attendance_rank_50
# Out:
#                   영화명                                배급사         개봉일  \
# 64                 명량                          (주)씨제이이엔엠  2014-07-30
# 28               극한직업                          (주)씨제이이엔엠  2019-01-23
# 105         신과함께-죄와 벌                      롯데쇼핑㈜롯데엔터테인먼트  2017-12-20
# 24               국제시장                          (주)씨제이이엔엠  2014-12-17
# 129        어벤져스: 엔드게임                 월트디즈니컴퍼니코리아 유한책임회사  2019-04-24
# 13             겨울왕국 2                 월트디즈니컴퍼니코리아 유한책임회사  2019-11-21
# 85                베테랑                          (주)씨제이이엔엠  2015-08-05
# 113               아바타          주식회사 해리슨앤컴퍼니,이십세기폭스코리아(주)  2009-12-17
# 51                도둑들                             (주)쇼박스  2012-07-25
# 3             7번방의 선물                (주)넥스트엔터테인먼트월드(NEW)  2013-01-23
# 121               알라딘                 월트디즈니컴퍼니코리아 유한책임회사  2019-05-23
# 122                암살                             (주)쇼박스  2015-07-22
# 81              범죄도시2        주식회사 에이비오엔터테인먼트,플러스엠 엔터테인먼트  2022-05-18
# ...

# %% [markdown]
# # 코로나 유행 이후(2020년 이후 개봉 영화)

# %%
mv_name = attendance_rank_50['영화명']
attendance_val = attendance_rank_50['관객수']
sales_val = attendance_rank_50['매출액']
release_year = attendance_rank_50['개봉년도']

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 13))
fig.set_facecolor('white')

# 컬러맵 선택
cmap = cm.get_cmap('tab10')

# 조건에 따라 색상 지정
colors = ['dodgerblue' if year < 2020 else 'salmon' for year in release_year]

# 관객수 시각화
ax1.bar(mv_name, attendance_val, color=colors)
ax1.set_ylabel('관객수')

# 매출액 시각화
ax2.bar(mv_name, sales_val, color=colors)
ax2.set_ylabel('매출액')

# x축 라벨 설정
plt.setp(ax1.get_xticklabels(), rotation=45, ha='right', fontsize=10)
plt.setp(ax2.get_xticklabels(), rotation=45, ha='right', fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_9500\3676743862.py:10: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('tab10')

# %% [markdown]
# # 2010년 이전 개봉 영화

# %%
mv_name = attendance_rank_50['영화명']
attendance_val = attendance_rank_50['관객수']
sales_val = attendance_rank_50['매출액']
release_year = attendance_rank_50['개봉년도']

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 13))
fig.set_facecolor('white')

# 컬러맵 선택
cmap = cm.get_cmap('tab10')

# 조건에 따라 색상 지정
colors = ['dodgerblue' if year < 2010 else 'salmon' for year in release_year]

# 관객수 시각화
ax1.bar(mv_name, attendance_val, color=colors)
ax1.set_ylabel('관객수')

# 매출액 시각화
ax2.bar(mv_name, sales_val, color=colors)
ax2.set_ylabel('매출액')

# x축 라벨 설정
plt.setp(ax1.get_xticklabels(), rotation=45, ha='right', fontsize=10)
plt.setp(ax2.get_xticklabels(), rotation=45, ha='right', fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_9500\2423711408.py:10: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('tab10')
