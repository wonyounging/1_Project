# %%
import pandas as pd
import numpy as np

# %%
file = './resources/Public_전국_영화상영관_ver1.xlsx'
df_mv_t = pd.read_csv(file, engine='openpyxl')
df_mv_t
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 file = './resources/Public_전국_영화상영관_ver1.xlsx'
# ----> 2 df_mv_t = pd.read_excel(file, engine='openpyxl')
#       3 df_mv_t
#
# File c:\python38\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\python38\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# ...

# %%
file_mv_csv = './resources/Public_전국_영화상영관_ver1.csv'
df_mv_t_csv = pd.read_csv(file_mv_csv, encoding='CP949')
df_mv_t_csv
# Out:
#      개방서비스명   개방자치단체코드       인허가일자  영업상태명 소재지전화                소재지전체주소  \
# 0       NaN        NaN         NaN    NaN   NaN                    NaN
# 1       NaN        NaN         NaN    NaN   NaN                    NaN
# 2       NaN        NaN         NaN    NaN   NaN                    NaN
# 3       NaN        NaN         NaN    NaN   NaN                    NaN
# 4       NaN        NaN         NaN    NaN   NaN                    NaN
# ...     ...        ...         ...    ...   ...                    ...
# 4931  영화상영관  3220000.0  2000-05-04  영업/정상   NaN  서울특별시 강남구 삼성동 159-0번지
# 4932  영화상영관  3220000.0  2000-05-04  영업/정상   NaN  서울특별시 강남구 삼성동 159-0번지
# 4933  영화상영관  3220000.0  2000-05-04  영업/정상   NaN  서울특별시 강남구 삼성동 159-0번지
# 4934  영화상영관  3220000.0  2000-05-04  영업/정상   NaN  서울특별시 강남구 삼성동 159-0번지
# 4935  영화상영관  3220000.0  2000-05-04  영업/정상   NaN  서울특별시 강남구 삼성동 159-0번지
#
#                         도로명전체주소
# 0                           NaN
# 1                           NaN
# ...

# %%
df_mv_t_csv.isna()
# Out:
#       개방서비스명  개방자치단체코드  인허가일자  영업상태명  소재지전화  소재지전체주소  도로명전체주소
# 0       True      True   True   True   True     True     True
# 1       True      True   True   True   True     True     True
# 2       True      True   True   True   True     True     True
# 3       True      True   True   True   True     True     True
# 4       True      True   True   True   True     True     True
# ...      ...       ...    ...    ...    ...      ...      ...
# 4931   False     False  False  False   True    False    False
# 4932   False     False  False  False   True    False    False
# 4933   False     False  False  False   True    False    False
# 4934   False     False  False  False   True    False    False
# 4935   False     False  False  False   True    False    False
#
# [4936 rows x 7 columns]

# %%
df_mv_t_csv = df_mv_t_csv.dropna()

# %%
df_mv_t_csv
# Out:
#      개방서비스명   개방자치단체코드       인허가일자  영업상태명          소재지전화  \
# 1225  영화상영관  3600000.0  2009-05-19  영업/정상   062-369-3572
# 1226  영화상영관  3600000.0  2009-05-19  영업/정상   062-369-3572
# 1227  영화상영관  3600000.0  2009-05-19  영업/정상   062-369-3572
# 1228  영화상영관  3600000.0  2009-05-19  영업/정상   062-369-3572
# 1229  영화상영관  3600000.0  2009-05-27  영업/정상   062-369-3572
# ...     ...        ...         ...    ...            ...
# 4760  영화상영관  4400000.0  2022-04-28  영업/정상      436531778
# 4767  영화상영관  4470000.0  2022-05-17  영업/정상  070-7704-7788
# 4768  영화상영관  4470000.0  2022-05-17  영업/정상  070-7704-7788
# 4774  영화상영관  4550000.0  2022-04-29  영업/정상   041-751-7668
# 4775  영화상영관  4550000.0  2022-04-29  영업/정상   041-750-7668
#
#                                 소재지전체주소                         도로명전체주소
# 1225      광주광역시 서구 광천동 49-1 유스퀘어(광천터미널)         광주광역시 서구 무진대로 904 (광천동)
# 1226      광주광역시 서구 광천동 49-1 유스퀘어(광천터미널)         광주광역시 서구 무진대로 904 (광천동)
# ...

# %%
df_mv_t_csv.loc[df_mv_t_csv.groupby(['소재지전화'])[''].idxmax()]

# %%
df_mv_t_csv.index
# Out:
# Int64Index([1225, 1226, 1227, 1228, 1229, 1230, 1231, 1233, 1234, 1235,
#             ...
#             4755, 4756, 4757, 4758, 4759, 4760, 4767, 4768, 4774, 4775],
#            dtype='int64', length=2599)

# %%
df_mv_t_csv.index[(df_mv_t_csv['소재지전화'] == '062-369-3572')].tolist()
# Out:
# [1225, 1226, 1227, 1228, 1229, 1617, 1618, 1619, 1620]

# %%
df_mv_t_csv2 = df_mv_t_csv.drop_duplicates()

# %%
df_mv_t_csv2.index[(df_mv_t_csv2['소재지전화'] == '062-369-3572')].tolist()
# Out:
# [1225, 1229]

# %%
df_mv_t_csv2.to_csv('./resources/Public_전국_영화상영관_ver3.csv', index=False, encoding='CP949')

# %%
df_mv_t_csv2
# Out:
#      개방서비스명   개방자치단체코드       인허가일자  영업상태명          소재지전화  \
# 1225  영화상영관  3600000.0  2009-05-19  영업/정상   062-369-3572
# 1229  영화상영관  3600000.0  2009-05-27  영업/정상   062-369-3572
# 1230  영화상영관  3600000.0  2011-08-09  영업/정상    02-371-6505
# 1231  영화상영관  3590000.0  1999-05-08  영업/정상       224-5858
# 1233  영화상영관  3590000.0  2000-06-19  영업/정상       221-1940
# ...     ...        ...         ...    ...            ...
# 4746  영화상영관  3120000.0  2020-12-08  영업/정상  070-7780-0962
# 4755  영화상영관  4400000.0  2022-04-28  영업/정상      436531778
# 4767  영화상영관  4470000.0  2022-05-17  영업/정상  070-7704-7788
# 4774  영화상영관  4550000.0  2022-04-29  영업/정상   041-751-7668
# 4775  영화상영관  4550000.0  2022-04-29  영업/정상   041-750-7668
#
#                                 소재지전체주소                           도로명전체주소
# 1225      광주광역시 서구 광천동 49-1 유스퀘어(광천터미널)           광주광역시 서구 무진대로 904 (광천동)
# 1229      광주광역시 서구 광천동 49-1 유스퀘어(광천터미널)           광주광역시 서구 무진대로 904 (광천동)
# ...

# %%
df_mv_t_csv2['인허가일자'] = pd.to_datetime(df_mv_t_csv2['인허가일자'], format='%Y-%m-%d')
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_12112\3145093963.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mv_t_csv2['인허가일자'] = pd.to_datetime(df_mv_t_csv2['인허가일자'], format='%Y-%m-%d')

# %%
df_new = df_mv_t_csv2.loc[df_mv_t_csv2.groupby('도로명전체주소')['인허가일자'].idxmax()]
df_new
# Out:
#      개방서비스명   개방자치단체코드      인허가일자  영업상태명          소재지전화  \
# 2695  영화상영관  4200000.0 2012-03-16  영업/정상   033-645-7415
# 2687  영화상영관  4200000.0 2009-09-07  영업/정상   033-655-7288
# 2696  영화상영관  4200000.0 2017-07-13  영업/정상   033-645-7200
# 3914  영화상영관  4340000.0 2002-02-10  영업/정상   033-681-4146
# 2934  영화상영관  4340000.0 2022-01-05  영업/정상   033-680-4068
# ...     ...        ...        ...    ...            ...
# 4417  영화상영관  5710000.0 2012-11-07  영업/정상  070-7465-3802
# 4405  영화상영관  5710000.0 2004-02-16  영업/정상   043-233-9525
# 4435  영화상영관  5710000.0 2014-04-21  영업/정상    02-371-6670
# 4282  영화상영관  4390000.0 2021-04-12  영업/정상  070-7525-0037
# 4532  영화상영관  4390000.0 2013-01-24  영업/정상       857-7020
#
#                                소재지전체주소                             도로명전체주소
# 2695               강원도 강릉시 임당동 119-3번지          강원도 강릉시 경강로 2100, 4층 (임당동)
# 2687                강원도 강릉시 옥천동 189 7층              강원도 강릉시 경강로 2120 (옥천동)
# ...

# %%
df_new[df_new['도로명전체주소'] == '광주광역시 서구 무진대로 904 (광천동)']
# Out:
#      개방서비스명   개방자치단체코드      인허가일자  영업상태명         소재지전화  \
# 1229  영화상영관  3600000.0 2009-05-27  영업/정상  062-369-3572
#
#                             소재지전체주소                  도로명전체주소
# 1229  광주광역시 서구 광천동 49-1 유스퀘어(광천터미널)  광주광역시 서구 무진대로 904 (광천동)

# %%
df_mv_t_csv2[df_mv_t_csv2['도로명전체주소'] == '광주광역시 서구 무진대로 904 (광천동)']
# Out:
#      개방서비스명   개방자치단체코드      인허가일자  영업상태명         소재지전화  \
# 1225  영화상영관  3600000.0 2009-05-19  영업/정상  062-369-3572
# 1229  영화상영관  3600000.0 2009-05-27  영업/정상  062-369-3572
#
#                             소재지전체주소                  도로명전체주소
# 1225  광주광역시 서구 광천동 49-1 유스퀘어(광천터미널)  광주광역시 서구 무진대로 904 (광천동)
# 1229  광주광역시 서구 광천동 49-1 유스퀘어(광천터미널)  광주광역시 서구 무진대로 904 (광천동)

# %%
df_new.head()
# Out:
#      개방서비스명   개방자치단체코드      인허가일자  영업상태명         소재지전화  \
# 2695  영화상영관  4200000.0 2012-03-16  영업/정상  033-645-7415
# 2687  영화상영관  4200000.0 2009-09-07  영업/정상  033-655-7288
# 2696  영화상영관  4200000.0 2017-07-13  영업/정상  033-645-7200
# 3914  영화상영관  4340000.0 2002-02-10  영업/정상  033-681-4146
# 2934  영화상영관  4340000.0 2022-01-05  영업/정상  033-680-4068
#
#                            소재지전체주소                     도로명전체주소
# 2695           강원도 강릉시 임당동 119-3번지  강원도 강릉시 경강로 2100, 4층 (임당동)
# 2687            강원도 강릉시 옥천동 189 7층      강원도 강릉시 경강로 2120 (옥천동)
# 2696     강원도 강릉시 구정면 어단리 478-132번지        강원도 강릉시 구정면 칠성로 13-8
# 3914         강원도 고성군 간성읍 하리 27-1번지        강원도 고성군 간성읍 간성로 71-7
# 2934  강원도 고성군 간성읍 신안리 146-3 달홀문화센터   강원도 고성군 간성읍 수성로 3, 달홀문화센터

# %%
df_new.to_csv('./resources/Public_전국_영화상영관_ver4.csv', index=False, encoding='CP949')
