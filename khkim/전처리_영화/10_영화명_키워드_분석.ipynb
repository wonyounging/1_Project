# %% [markdown]
# # 1. 파일불러오기

# %%
import pandas as pd
import numpy as np

# %%
from matplotlib import font_manager, rc
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['axes.unicode_minus'] = False  # minus 표시
plt.rc('font', family='Malgun Gothic')

# %%
file_path = './resources/완_기간별_ordered_180101_to_230509_ver3.csv'
mv_2018 = pd.read_csv(file_path)
print(mv_2018.columns)
mv_2018.head()
# Out:
# Index(['순위', '영화명', '개봉일', '대표국적', '국적', '제작사', '배급사', '등급', '장르', '감독', '배우',
#        '기준일', '매출액', '누적매출액', '관객수', '누적관객수', '스크린수', '상영횟수', '기준연도', '기준월',
#        '개봉연도', '개봉월'],
#       dtype='object')
#    순위                영화명         개봉일 대표국적  국적                        제작사  \
# 0   1          신과함께-죄와 벌  2017-12-20   한국  한국     리얼라이즈픽쳐스(주),(주)덱스터스튜디오
# 1   2               1987  2017-12-27   한국  한국                    (주)우정필름
# 2   4                강철비  2017-12-14   한국  한국  (주)와이웍스엔터테인먼트,(주)브이에이스튜디오
# 3   5             위대한 쇼맨  2017-12-20   미국  미국                        NaN
# 4   7  극장판 포켓몬스터 너로 정했다!  2017-12-21   일본  일본                        NaN
#
#                                배급사        등급             장르        감독  ...  \
# 0                    롯데쇼핑㈜롯데엔터테인먼트  12세이상관람가        판타지,드라마       김용화  ...
# 1                        (주)씨제이이엔엠  15세이상관람가            드라마       장준환  ...
# 2              (주)넥스트엔터테인먼트월드(NEW)  15세이상관람가         액션,드라마       양우석  ...
# 3  월트디즈니컴퍼니코리아 유한책임회사,이십세기폭스코리아(주)  12세이상관람가        드라마,뮤지컬  마이클 그레이시  ...
# 4                         (주)이수C&E     전체관람가  애니메이션,어드벤처,가족  유야마 쿠니히코  ...
#
#           매출액        누적매출액     관객수    누적관객수  스크린수  상영횟수  기준연도  기준월  개봉연도  개봉월
# 0  7715149100  76065645532  916652  9456147  1644  7957  2018    1  2017   12
# 1  4460462100  19714466137  531469  2473546  1097  4982  2018    1  2017   12
# 2   944228600  32939126166  114298  4128591   602  1451  2018    1  2017   12
# 3   509947700   7166974900   60070   874655   432   843  2018    1  2017   12
# 4   262886500   3380416200   34103   449358   417   605  2018    1  2017   12
#
# [5 rows x 22 columns]

# %%
file_path2 = './resources/(완)역대_박스오피스(2023.05.11).xlsx'
mv_top200 = pd.read_excel(file_path2)
print(mv_top200.columns)
mv_top200
# Out:
# Index(['순위', '영화명', '개봉일', '매출액', '관객수', '스크린수', '상영횟수', '대표국적', '국적', '배급사'], dtype='object')
#       순위          영화명        개봉일           매출액       관객수  스크린수    상영횟수 대표국적  \
# 0      1           명량 2014-07-30  135758658810  17615919  1587  188726   한국
# 1      2         극한직업 2019-01-23  139655543516  16266338  2003  292816   한국
# 2      3    신과함께-죄와 벌 2017-12-20  115727528087  14414658  1912  214631   한국
# 3      4         국제시장 2014-12-17  110947621230  14264478  1044  212705   한국
# 4      5   어벤져스: 엔드게임 2019-04-24  122492181020  13977602  2835  246433   미국
# ..   ...          ...        ...           ...       ...   ...     ...  ...
# 195  196  해리 포터와 불의 잔 2005-12-01   22097731900   3499257   504   45555   미국
# 196  197       비긴 어게인 2014-08-13   27433947031   3479444   525   87565   미국
# 197  198           태풍 2005-12-14   22209675300   3471150   481   47155   한국
# 198  199           킹콩 2005-12-14   21476688172   3470059   319   38456   미국
# 199  200       부러진 화살 2012-01-18   25938096000   3460212   530   71607   한국
#
#      국적                  배급사
# 0    한국            (주)씨제이이엔엠
# 1    한국            (주)씨제이이엔엠
# 2    한국        롯데쇼핑㈜롯데엔터테인먼트
# 3    한국            (주)씨제이이엔엠
# 4    미국   월트디즈니컴퍼니코리아 유한책임회사
# ..   ..                  ...
# 195  미국        워너브러더스 코리아(주)
# 196  미국              판씨네마(주)
# 197  한국               CJ ENM
# 198  미국               UIP코리아
# 199  한국  (주)넥스트엔터테인먼트월드(NEW)
#
# [200 rows x 10 columns]

# %%
mv_top200_country = mv_top200.groupby('대표국적')['영화명'].count().reset_index(name='영화별대표국적수')
mv_top200_country = mv_top200_country.sort_values(by='영화별대표국적수', ascending=False)
mv_top200_country
# Out:
#   대표국적  영화별대표국적수
# 2   한국       114
# 0   미국        83
# 1   일본         3

# %% [markdown]
# # 2. 영화명 키워드 분석

# %%
mv_2018['기준일'] = pd.to_datetime(mv_2018['기준일'],format='%Y-%m-%d')

# %%
mv_gp = mv_2018.loc[mv_2018.groupby(['영화명'])['기준일'].idxmax()]
mv_gp
# Out:
#          순위                영화명         개봉일 대표국적   국적                제작사  \
# 82339    66              #살아있다  2020-06-24   한국   한국  영화사 집,(주)퍼스펙티브픽쳐스
# 91453   115             #아이엠히어  2021-01-14  프랑스  프랑스                NaN
# 142789  134              #위왓치유  2021-06-03   기타   기타                NaN
# 129956   84              #해시태그  2022-06-01   한국   한국        (주)더존크리에이티브
# 42948   175             0.0MHz  2019-05-29   한국   한국          (주)제이엠컬쳐스
# ...     ...                ...         ...  ...  ...                ...
# 127938  215     힐링하우스 : 섹스의 왕국  2022-05-10   한국   한국        (주)라온컴퍼니플러스
# 97608   224            힐빌리의 노래  2020-11-11   미국   미국                NaN
# 94294   180  힘 좋은 시아버지와 착한 며느리  2021-03-18   한국   한국           (주)나우콘텐츠
# 58639    39       힘을 내요, 미스터 리  2019-09-11   한국   한국  (주)용필름,(주)덱스터스튜디오
# 41095   232      힘좋은 시아버지와 베란다  2019-06-03   일본   일본                NaN
#
#                         배급사        등급              장르                감독  ...  \
# 82339     롯데컬처웍스(주)롯데엔터테인먼트  15세이상관람가             드라마               조일형  ...
# 91453   (주)넥스트엔터테인먼트월드(NEW)  12세이상관람가      멜로/로맨스,코미디            에릭 라티고  ...
# 142789                   찬란   청소년관람불가           다큐멘터리  바르보라 차르포바,비트 클루삭  ...
# 129956          (주)더존크리에이티브  12세이상관람가              공연               이상식  ...
# 42948             (주)스마일이엔티  15세이상관람가          공포(호러)               유선동  ...
# ...                     ...       ...             ...               ...  ...
# 127938             (주)가온콘텐츠   청소년관람불가  성인물(에로),멜로/로맨스               윤수현  ...
# 97608           플러스엠 엔터테인먼트   청소년관람불가             드라마             론 하워드  ...
# 94294              (주)나우콘텐츠   청소년관람불가      멜로/로맨스,드라마               송정규  ...
# 58639   (주)넥스트엔터테인먼트월드(NEW)  12세이상관람가         코미디,드라마               이계벽  ...
# 41095           (주)도키엔터테인먼트   청소년관람불가         성인물(에로)            스즈키 켄지  ...
#
#              매출액        누적매출액   관객수    누적관객수  스크린수  상영횟수  기준연도  기준월  개봉연도  개봉월
# 82339    2890000  15968219900   289  1903992     2     2  2020   10  2020    6
# 91453      82000    136875710    11    16404     6     6  2021    2  2021    1
# 142789    288000     16759950    48     1908     1     1  2022   11  2021    6
# 129956    420500      2205600    35      173     8     8  2022    6  2022    6
# 42948      84000   1088258860    12   137294     1     1  2019    6  2019    5
# ...          ...          ...   ...      ...   ...   ...   ...  ...   ...  ...
# 127938      6000         6000     1        1     1     1  2022    5  2022    5
# 97608      46000     34016080     8     4027     1     1  2021    4  2020   11
# 94294     100000       100000    20       20     1     1  2021    3  2021    3
# 58639   10950000   9930518906  1095  1181960     5     5  2019   12  2019    9
# 41095       6000         6000     1        1     1     1  2019    6  2019    6
#
# [10106 rows x 22 columns]
